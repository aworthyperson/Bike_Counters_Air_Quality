# %%
#import packages


import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon, box
import fiona
import pyproj
import contextily as ctx
import os
import requests
import matplotlib.ticker as ticker
import scipy.stats as stats
import matplotlib.pyplot as plt
from matplotlib import pyplot
from matplotlib.ticker import PercentFormatter
import requests
import matplotlib.colors as colors

#%matplotlib widget
# %matplotlib inline

# %% [markdown]
# ## Things to do
#
# 1. Look at how AQ is influencing biking

# %% [markdown]
# ## SDOT Bike Counter Data:
#
#
# https://data.seattle.gov/browse?category=Transportation&limitTo=datasets&q=&sortBy=relevance&page=1

# %% [markdown]
# # Freemont Bike Data
# - operating fom
# 2012-10-03 00:00:00 to 2022-09-30 23:00:00

# %%
bike= pd.read_csv("Data/Fremont_Bridge_Bicycle_Counter.csv", sep=',')
bike.Date= pd.to_datetime(bike.Date)
bike.head()

#bike.to_csv('Data/bikef.csv')
# Out:
#                  Date  Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# 0 2022-08-01 00:00:00                  23.0                           7.0
# 1 2022-08-01 01:00:00                  12.0                           5.0
# 2 2022-08-01 02:00:00                   3.0                           0.0
# 3 2022-08-01 03:00:00                   5.0                           2.0
# 4 2022-08-01 04:00:00                  10.0                           2.0
#
#    Fremont Bridge West Sidewalk
# 0                          16.0
# 1                           7.0
# 2                           3.0
# 3                           3.0
# 4                           8.0

# %%
fig,ax = plt.subplots(figsize=(18,10))

ax.set_title('Fremont Bridge Total')

bike.plot(x='Date', y='Fremont Bridge Total',color='k', markerfacecolor='white', ax=ax)

ax.set_xlabel("Time",fontsize=14)

ax.set_ylabel("Fremont Bridge Daily Bike Counts",color='k',fontsize=14);

# %%
print(bike.Date.min())
print(bike.Date.max())
# Out:
# 2012-10-03 00:00:00
# 2022-09-30 23:00:00

# %% [markdown]
# # Spokane Street Bridge (West Seattle)
#
# 2014-01-01 00:00:00
# 2022-09-30 23:00:00

# %%
bikess= pd.read_csv("Data/Spokane_St_Bridge_Bicycle_Counter.csv", sep=',')
bikess.Date= pd.to_datetime(bikess.Date)
bikess

#bikess.to_csv('Data/bikess.csv')
# Out:
#                      Date  Spokane St. Bridge Total  West  East
# 0     2020-06-01 00:00:00                       2.0   2.0   0.0
# 1     2020-06-01 01:00:00                       1.0   0.0   1.0
# 2     2020-06-01 02:00:00                       2.0   2.0   0.0
# 3     2020-06-01 03:00:00                       1.0   0.0   1.0
# 4     2020-06-01 04:00:00                       3.0   1.0   2.0
# ...                   ...                       ...   ...   ...
# 78139 2022-09-30 19:00:00                      54.0   7.0  47.0
# 78140 2022-09-30 20:00:00                      27.0  14.0  13.0
# 78141 2022-09-30 21:00:00                      34.0  18.0  16.0
# 78142 2022-09-30 22:00:00                      28.0   6.0  22.0
# 78143 2022-09-30 23:00:00                      21.0   3.0  18.0
#
# [78144 rows x 4 columns]

# %%
print(bikess.Date.min())
print(bikess.Date.max())
# Out:
# 2014-01-01 00:00:00
# 2022-09-30 23:00:00

# %%
fig,ax = plt.subplots(figsize=(18,10))

ax.set_title('Spokane St. Bridge Total')

bikess.plot(x='Date', y='Spokane St. Bridge Total',color='k', markerfacecolor='white', ax=ax)

ax.set_xlabel("Time",fontsize=14)

ax.set_ylabel("Spokane St.Bridge Daily Bike Counts",color='k',fontsize=14);

# %%
result =pd.merge(left= bike, right=bikess, on = ['Date'])
result

daily =result.set_index('Date').resample('1D').sum(min_count=24)
daily= daily.reset_index()
daily

monthly =daily.set_index('Date').resample('1M').sum(min_count=27)
monthly= monthly.reset_index()
monthly

yearly =monthly.set_index('Date').resample('1Y').sum(min_count=11)
yearly


result['time_hour'] = result.Date.dt.hour
result['time_yr'] = result.Date.dt.year
result['DOW'] = bikess.Date.dt.dayofweek
result['time_mn'] = result.Date.dt.month
result
# Out:
#                      Date  Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# 0     2022-08-01 00:00:00                  23.0                           7.0
# 1     2022-08-01 01:00:00                  12.0                           5.0
# 2     2022-08-01 02:00:00                   3.0                           0.0
# 3     2022-08-01 03:00:00                   5.0                           2.0
# 4     2022-08-01 04:00:00                  10.0                           2.0
# ...                   ...                   ...                           ...
# 75907 2022-09-30 19:00:00                 168.0                          57.0
# 75908 2022-09-30 20:00:00                  73.0                          33.0
# 75909 2022-09-30 21:00:00                  69.0                          30.0
# 75910 2022-09-30 22:00:00                  51.0                          10.0
# 75911 2022-09-30 23:00:00                  59.0                          22.0
#
#        Fremont Bridge West Sidewalk  Spokane St. Bridge Total  West  East  \
# 0                              16.0                       4.0   0.0   4.0
# 1                               7.0                       1.0   1.0   0.0
# 2                               3.0                       2.0   0.0   2.0
# 3                               3.0                       2.0   2.0   0.0
# 4                               8.0                       8.0   7.0   1.0
# ...                             ...                       ...   ...   ...
# 75907                         111.0                      54.0   7.0  47.0
# 75908                          40.0                      27.0  14.0  13.0
# 75909                          39.0                      34.0  18.0  16.0
# 75910                          41.0                      28.0   6.0  22.0
# 75911                          37.0                      21.0   3.0  18.0
#
#        time_hour  time_yr  DOW  time_mn
# 0              0     2022    0        8
# 1              1     2022    0        8
# 2              2     2022    0        8
# 3              3     2022    0        8
# 4              4     2022    0        8
# ...          ...      ...  ...      ...
# 75907         19     2022    2        9
# 75908         20     2022    2        9
# 75909         21     2022    2        9
# 75910         22     2022    2        9
# 75911         23     2022    2        9
#
# [75912 rows x 11 columns]

# %%
daily['time_hour'] = daily.Date.dt.hour
daily['time_yr'] = daily.Date.dt.year
daily['DOW'] = daily.Date.dt.dayofweek

daily.head()
# Out:
#         Date  Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# 0 2014-01-01                 914.0                         498.0
# 1 2014-01-02                1865.0                         931.0
# 2 2014-01-03                2027.0                        1079.0
# 3 2014-01-04                1172.0                         657.0
# 4 2014-01-05                1151.0                         665.0
#
#    Fremont Bridge West Sidewalk  Spokane St. Bridge Total   West   East  \
# 0                         416.0                     246.0  121.0  125.0
# 1                         934.0                     496.0  233.0  263.0
# 2                         948.0                     510.0  238.0  272.0
# 3                         515.0                     420.0  190.0  230.0
# 4                         486.0                     289.0  144.0  145.0
#
#    time_hour  time_yr  DOW
# 0          0     2014    2
# 1          0     2014    3
# 2          0     2014    4
# 3          0     2014    5
# 4          0     2014    6

# %%
monthly['time_mn'] = monthly.Date.dt.month
monthly['time_yr'] = monthly.Date.dt.year


monthly.head()
# Out:
#         Date  Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# 0 2014-01-31               59873.0                       30974.0
# 1 2014-02-28               47025.0                       24086.0
# 2 2014-03-31               62352.0                       32202.0
# 3 2014-04-30               86855.0                       44859.0
# 4 2014-05-31              118644.0                       61462.0
#
#    Fremont Bridge West Sidewalk  Spokane St. Bridge Total     West     East  \
# 0                       28899.0                   16249.0   7727.0   8522.0
# 1                       22939.0                   12652.0   6071.0   6581.0
# 2                       30150.0                   17396.0   8487.0   8909.0
# 3                       41996.0                   23891.0  11718.0  12173.0
# 4                       57182.0                   35207.0  17085.0  18122.0
#
#    time_mn  time_yr
# 0        1     2014
# 1        2     2014
# 2        3     2014
# 3        4     2014
# 4        5     2014

# %%
yearly= yearly.reset_index()
yearly['time_yr'] = yearly.Date.dt.year

yearly
# Out:
#         Date  Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# 0 2014-12-31             1005054.0                      514678.0
# 1 2015-12-31              981207.0                      498117.0
# 2 2016-12-31              982136.0                      468134.0
# 3 2017-12-31              962399.0                      412095.0
# 4 2018-12-31             1049509.0                      424456.0
# 5 2019-12-31             1185678.0                      449116.0
# 6 2020-12-31              771299.0                      323302.0
# 7 2021-12-31              713191.0                      294913.0
# 8 2022-12-31                   NaN                           NaN
#
#    Fremont Bridge West Sidewalk  Spokane St. Bridge Total      West      East  \
# 0                      490376.0                  282399.0  137284.0  145115.0
# 1                      483090.0                  298816.0  147291.0  151525.0
# 2                      514002.0                  297361.0  146093.0  151268.0
# 3                      550304.0                  275339.0  135474.0  139865.0
# 4                      625053.0                  291934.0  143828.0  148106.0
# 5                      736562.0                  321298.0  158482.0  162816.0
# 6                      447997.0                  285186.0  140575.0  144611.0
# 7                      418278.0                  229960.0  115463.0  114497.0
# 8                           NaN                       NaN       NaN       NaN
#
#    time_yr
# 0     2014
# 1     2015
# 2     2016
# 3     2017
# 4     2018
# 5     2019
# 6     2020
# 7     2021
# 8     2022

# %%
import matplotlib.pyplot as plt
import seaborn


fig, (ax, ax1) = plt.subplots(nrows=2, ncols=1,figsize=(16,12))
seaborn.boxplot(x = result.time_hour, 
                y = result['Spokane St. Bridge Total'],
                ax = ax)


ax.set(ylabel='Spokane St. Bridge Hourly Bike Counts',
       xlabel='Hour of Day',
       title='Bike Counts Observed at each hour of day at the Spokane St. Bridge');



seaborn.boxplot(x = result.time_hour, 
                y = result['Fremont Bridge Total'],
                ax = ax1)


ax1.set(ylabel='Fremont Bridge Hourly Bike Counts',
       xlabel='Hour of Day',
       title='Bike Counts Observed at each hour of day at the Fremont Bridge');
#plt.savefig('box_plot_hour.pdf')

# %%
import matplotlib.pyplot as plt
import seaborn


fig, (ax, ax1) = plt.subplots(nrows=2, ncols=1,figsize=(16,12))
seaborn.boxplot(x = result.time_hour, 
                y = result['East'],
                ax = ax)


ax.set(ylabel='Spokane St. Bridge Hourly Bike Counts going East',
       xlabel='Hour of Day',
       title='East Bike Counts Observed at each hour of day at the Spokane St. Bridge');



seaborn.boxplot(x = result.time_hour, 
                y = result['West'],
                ax = ax1)


ax1.set(ylabel='Spokane St. Bridge Hourly Bike Counts going West',
       xlabel='Hour of Day',
       title='West Bike Counts Observed at each hour of day at the Spokane St. Bridge');
#plt.savefig('box_plot_hour.pdf')

# %%
import matplotlib.pyplot as plt
import seaborn


fig, (ax, ax1) = plt.subplots(nrows=2, ncols=1,figsize=(16,12))
seaborn.boxplot(x = daily.DOW, 
                y = daily['Spokane St. Bridge Total'],
                ax = ax)


ax.set(ylabel='Spokane St. Bridge Daily Bike Counts',
       xlabel='Day of Week',
       title='Bike Counts Observed Daily at the Spokane St. Bridge');



seaborn.boxplot(x = daily.DOW, 
                y = daily['Fremont Bridge Total'],
                ax = ax1)


ax1.set(ylabel='Fremont Bridge Daily Bike Counts',
       xlabel='Day of Week',
       title='Bike Counts Observed Daily at the Fremont Bridge');
#plt.savefig('box_plot_hour.pdf')

# %%
import matplotlib.pyplot as plt
import seaborn


fig, (ax, ax1) = plt.subplots(nrows=2, ncols=1,figsize=(16,12))
seaborn.boxplot(x = monthly.time_mn, 
                y = monthly['Spokane St. Bridge Total'],
                ax = ax)


ax.set(ylabel='Spokane St. Bridge Daily Bike Counts',
       xlabel='Month',
       title='Bike Counts Observed Monthly at the Spokane St. Bridge');



seaborn.boxplot(x = monthly.time_mn, 
                y = monthly['Fremont Bridge Total'],
                ax = ax1)


ax1.set(ylabel='Fremont Bridge Monthly Bike Counts',
       xlabel='Month',
       title='Bike Counts Observed Monthly at the Fremont Bridge');
#plt.savefig('box_plot_hour.pdf')

# %%
import matplotlib.pyplot as plt
import seaborn


fig, (ax) = plt.subplots(nrows=1, ncols=1,figsize=(10,6))
seaborn.lineplot(x = yearly.time_yr, 
                y = yearly['Spokane St. Bridge Total'],
                ax = ax, label= 'Spokane Street Bridge')



seaborn.lineplot(x = yearly.time_yr, 
                y = yearly['Fremont Bridge Total'],
                ax = ax, label= 'Freemont Bridge')


ax.set(ylabel='Annual Bike Counts',
       xlabel='Year',
       title='Bike Counts Observed Annually at Seattle Bike Counters');
#plt.savefig('box_plot_hour.pdf')

# %% [markdown]
# ## Calculate AQI from Concentrations
#
# - https://github.com/ThangLeQuoc/aqi-calculator
# - https://www.kaggle.com/code/rohanrao/calculating-aqi-air-quality-index-tutorial/notebook
#
# #### Technical DOC from the EPA
#
# - https://www.airnow.gov/sites/default/files/2020-05/aqi-technical-assistance-document-sept2018.pdf

# %%
df= pd.read_csv("Data/AQ_Percip.csv", sep=',')
df.Date =pd.to_datetime(df.Date)
df['DOY'] = df.Date.dt.date

print(df.shape)

print(df.Date.max())
print(result.Date.max())
# Out:
# (167597, 17)
# 2022-11-14 14:00:00
# 2022-09-30 23:00:00

# %%
df= df.round(decimals=3)

print(df.shape)
df
# Out:
# (167597, 17)
#                          Site                Date      CO    NO2  NO2_caps  \
# 0       Seattle 10th & Weller 2015-01-01 00:00:00   699.3  27.86       NaN
# 1       Seattle 10th & Weller 2015-01-01 10:00:00   572.9  13.06       NaN
# 2       Seattle 10th & Weller 2015-01-01 11:00:00   738.8  20.25       NaN
# 3       Seattle 10th & Weller 2015-01-01 12:00:00  1055.1  31.14       NaN
# 4       Seattle 10th & Weller 2015-01-01 13:00:00   989.5  34.18       NaN
# ...                       ...                 ...     ...    ...       ...
# 167592    Seattle Beacon Hill 2022-09-09 05:00:00   131.7    NaN      6.90
# 167593    Seattle Beacon Hill 2022-09-09 06:00:00   148.7    NaN      7.86
# 167594    Seattle Beacon Hill 2022-09-09 07:00:00   151.5    NaN      8.19
# 167595    Seattle Beacon Hill 2022-09-09 08:00:00   162.4    NaN      8.07
# 167596    Seattle Beacon Hill 2022-09-09 09:00:00   167.7    NaN      6.78
#
#         ozone  PM2.5_MO  PM2.5_FEM  RH  SO2  Temperature  Temperature_10_m  \
# 0         NaN       NaN       25.5 NaN  NaN          NaN              32.0
# 1         NaN       NaN        8.6 NaN  NaN          NaN              34.0
# 2         NaN       NaN       12.8 NaN  NaN          NaN              37.0
# 3         NaN       NaN       19.8 NaN  NaN          NaN              39.0
# 4         NaN       NaN       16.3 NaN  NaN          NaN              41.0
# ...       ...       ...        ...  ..  ...          ...               ...
# 167592   0.01       4.0        NaN NaN  0.7          NaN              57.0
# 167593   0.01       5.0        NaN NaN  0.8          NaN              57.0
# 167594   0.01       6.0        NaN NaN  0.7          NaN              59.0
# 167595   0.01       4.0        NaN NaN  0.6          NaN              61.0
# 167596   0.02       4.0        NaN NaN  0.6          NaN              64.0
#
#         Wind_Direction_s  Wind_Direction_v  Wind_Speed_p  Wind_Speed_s  \
# 0                   26.0               NaN           NaN           2.8
# 1                  106.0               NaN           NaN           2.9
# 2                  127.0               NaN           NaN           2.9
# 3                  221.0               NaN           NaN           3.0
# 4                  226.0               NaN           NaN           3.2
# ...                  ...               ...           ...           ...
# 167592              25.0               NaN           NaN           NaN
# 167593              26.0               NaN           NaN           NaN
# 167594              27.0               NaN           NaN           NaN
# 167595              30.0               NaN           NaN           NaN
# 167596              36.0               NaN           NaN           NaN
#
#                DOY
# 0       2015-01-01
# 1       2015-01-01
# 2       2015-01-01
# 3       2015-01-01
# 4       2015-01-01
# ...            ...
# 167592  2022-09-09
# 167593  2022-09-09
# 167594  2022-09-09
# 167595  2022-09-09
# 167596  2022-09-09
#
# [167597 rows x 17 columns]

# %%
print(df.CO.min())
print(df.NO2.min())
print(df.NO2_caps.min())
print(df.ozone.min())
print(df['PM2.5_MO'].min())
print(df['PM2.5_FEM'].min())
print(df.RH.min())
print(df.SO2.min())
# Out:
# -500.1
# 0.0
# 0.42
# 0.0
# -15.0
# -10.0
# 11.0
# -0.7

# %%
df.loc[~(df['CO'] > 0), 'CO']=np.nan
df.loc[~(df['NO2'] > 0), 'NO2']=np.nan
df.loc[~(df['NO2_caps'] > 0), 'NO2_caps']=np.nan
df.loc[~(df['ozone'] > 0), 'ozone']=np.nan
df.loc[~(df['PM2.5_MO'] > 0), 'PM2.5_MO']=np.nan
df.loc[~(df['PM2.5_FEM'] > 0), 'PM2.5_FEM']=np.nan
df.loc[~(df['RH'] > 0), 'RH']=np.nan
df.loc[~(df['SO2'] > 0), 'SO2']=np.nan
df.loc[~(df['Temperature'] > 0), 'Temperature']=np.nan
df.loc[~(df['Temperature_10_m'] > 0), 'Temperature_10_m']=np.nan



print(df.CO.min())
print(df.NO2.min())
print(df.NO2_caps.min())
print(df.ozone.min())
print(df['PM2.5_MO'].min())
print(df['PM2.5_FEM'].min())
print(df.RH.min())
print(df.SO2.min())
print(df.Temperature.min())
print(df.Temperature_10_m.min())
# Out:
# 0.2
# 0.02
# 0.42
# 0.01
# 0.2
# 0.1
# 11.0
# 0.1
# 19.0
# 8.0

# %% [markdown]
# ![Screen Shot 2022-11-23 at 2.03.16 PM.png](attachment:a870b409-42e3-4b4f-a98b-bc22fc4bf609.png)

# %%
# Make sure Units are Consistent w EPA and my numbers 
df['ozone']= df['ozone']*1000 # in ppb (EPA) 
df['CO']= df['CO']/ 1000 # in ppm (EPA)

# %% [markdown]
# # Breakdowns of particulates
#
# - O3 (8 hr, 1 hr)
#         ozone CHECK
# - PM2.5 (24 hr)
#         PM2.5_MO CHECK
#         PM2.5_FEM CHECK
# - CO (8 hr)
#         CO CHECK
# - SO2 (1 hr)
#         SO2 CHECK
# - NO2 (1 hr)
#         NO2 CHECK
#         NO2_caps CHECK

# %%
df= df.sort_values(by= ['Date'])

df["Ozone_8hr_avg"] = df.groupby("Site")["ozone"].rolling(window = 8, min_periods = 4).mean().values
df["PM2.5_MO_24hr_avg"] = df.groupby("Site")["PM2.5_MO"].rolling(window = 24, min_periods = 16).mean().values
df["PM2.5_FEM_24hr_avg"] = df.groupby("Site")["PM2.5_FEM"].rolling(window = 24, min_periods = 16).mean().values
df["CO_8hr_avg"] = df.groupby("Site")["CO"].rolling(window = 8, min_periods = 4).mean().values

df
# Out:
#                         Site                Date      CO  NO2  NO2_caps  \
# 73522    Seattle Beacon Hill 2012-01-01 00:00:00     NaN  NaN       NaN
# 73533    Seattle Beacon Hill 2012-01-01 01:00:00     NaN  NaN       NaN
# 73538    Seattle Beacon Hill 2012-01-01 02:00:00     NaN  NaN       NaN
# 73539    Seattle Beacon Hill 2012-01-01 03:00:00     NaN  NaN       NaN
# 73540    Seattle Beacon Hill 2012-01-01 04:00:00     NaN  NaN       NaN
# ...                      ...                 ...     ...  ...       ...
# 13828  Seattle 10th & Weller 2022-11-14 12:00:00  0.2451  9.0       NaN
# 13829  Seattle 10th & Weller 2022-11-14 13:00:00  0.2136  8.5       NaN
# 91419    Seattle Beacon Hill 2022-11-14 13:00:00  0.2129  NaN      8.10
# 91420    Seattle Beacon Hill 2022-11-14 14:00:00  0.1864  NaN      6.18
# 13830  Seattle 10th & Weller 2022-11-14 14:00:00  0.2365  7.6       NaN
#
#        ozone  PM2.5_MO  PM2.5_FEM    RH  SO2  ...  Temperature_10_m  \
# 73522   10.0       NaN       10.3  71.0  NaN  ...               NaN
# 73533   30.0       NaN        3.0  64.0  NaN  ...               NaN
# 73538   30.0       NaN        2.3  65.0  NaN  ...               NaN
# 73539   30.0       NaN        NaN  66.0  NaN  ...               NaN
# 73540   20.0       NaN        3.5  67.0  NaN  ...               NaN
# ...      ...       ...        ...   ...  ...  ...               ...
# 13828    NaN      13.0        NaN   NaN  NaN  ...              49.0
# 13829    NaN       9.0        NaN   NaN  NaN  ...              51.0
# 91419   20.0       6.0        NaN   NaN  0.3  ...              51.0
# 91420   20.0       7.0        NaN   NaN  0.2  ...              52.0
# 13830    NaN       7.0        NaN   NaN  NaN  ...              52.0
#
#        Wind_Direction_s  Wind_Direction_v  Wind_Speed_p  Wind_Speed_s  \
# 73522               NaN             114.0           3.0           NaN
# 73533               NaN             131.0           5.6           NaN
# 73538               NaN              57.0           2.5           NaN
# 73539               NaN              69.0           1.6           NaN
# 73540               NaN              25.0           1.2           NaN
# ...                 ...               ...           ...           ...
# 13828              32.0               NaN           NaN           3.8
# 13829              29.0               NaN           NaN           4.7
# 91419              37.0               NaN           NaN           NaN
# 91420              15.0               NaN           NaN           NaN
# 13830              27.0               NaN           NaN           4.0
#
#               DOY Ozone_8hr_avg  PM2.5_MO_24hr_avg  PM2.5_FEM_24hr_avg  \
# 73522  2012-01-01           NaN                NaN                 NaN
# 73533  2012-01-01           NaN                NaN                 NaN
# 73538  2012-01-01           NaN                NaN                 NaN
# 73539  2012-01-01           NaN                NaN                 NaN
# 73540  2012-01-01           NaN                NaN                 NaN
# ...           ...           ...                ...                 ...
# 13828  2022-11-14         10.00          11.875000                 NaN
# 13829  2022-11-14         10.00          11.833333                 NaN
# 91419  2022-11-14         10.00          11.916667                 NaN
# 91420  2022-11-14         11.25          11.916667                 NaN
# 13830  2022-11-14         12.50          11.916667                 NaN
#
#        CO_8hr_avg
# 73522         NaN
# 73533         NaN
# 73538         NaN
# 73539         NaN
# 73540         NaN
# ...           ...
# 13828    0.216138
# 13829    0.225100
# 91419    0.229612
# 91420    0.229637
# 13830    0.224988
#
# [167597 rows x 21 columns]

# %% [markdown]
# ![68747470733a2f2f696d6167652e6962622e636f2f6776724663352f323031375f30375f32305f31355f32325f32312e706e67-1.png](attachment:6bfa0509-eb1a-47e7-b777-7d64cfbe5e6a.png)

# %%
## PM2.5 Sub-Index calculation
def get_PM25_subindex(x):
    if x <= 12:
        return ((50/12)* x)
    elif x <= 35.4:
        return (((50/(35.4 - 12.1 ))*(x - 12.1)))+ 50 
    elif x <= 55.4:
        return (((50/(55.4 - 35.5 ))*(x - 35.5)))+ 100 
    elif x <= 150.4:
        return (((50/(150.4- 55.5 ))*(x - 55.5)))+ 150 
    elif x <= 250.4:
        return (((100/(250.4- 150.5 ))*(x - 150.5)))+ 200 
    elif x <= 350.4:
        return (((100/(350.4- 250.5 ))*(x - 250.5)))+ 300 
    elif x >500:
        return (((100/(500- 350.5))*(x - 350.5)))+ 400 
    else:
        return 0

df["PM2.5MO_SubIndex"] = df["PM2.5_MO_24hr_avg"].apply(lambda x: get_PM25_subindex(x))
df["PM2.5FEM_SubIndex"] = df["PM2.5_FEM_24hr_avg"].apply(lambda x: get_PM25_subindex(x))
df["PM2.5_1hrMO_SubIndex"] = df["PM2.5_MO"].apply(lambda x: get_PM25_subindex(x))
df["PM2.5_1hrFEM_SubIndex"] = df["PM2.5_FEM"].apply(lambda x: get_PM25_subindex(x))

# %%
print(df['PM2.5_MO'].max())
print(df['PM2.5_FEM'].max())
# Out:
# 943.0
# 145.4

# %%
print(df["PM2.5_MO_24hr_avg"].max())
print(df["PM2.5_FEM_24hr_avg"].max())
# Out:
# 189.41666666666666
# 106.8625

# %%
print(df["PM2.5MO_SubIndex"].max())
print(df["PM2.5FEM_SubIndex"].max())
print(df["PM2.5_1hrMO_SubIndex"].max())
print(df["PM2.5_1hrFEM_SubIndex"].max())
# Out:
# 238.95562228895562
# 177.06138040042148
# 796.3210702341137
# 197.36564805057955

# %%
## O3 Sub-Index calculation
def get_03_subindex(x):
    if x <= 54:
        return ((50/54)* x)
    elif x <= 70:
        return ((50/(70- 55))*(x - 55))+ 50 
    elif x <= 85:
        return ((50/(85- 71))*(x - 71))+ 100 
    elif x <= 105:
        return ((50/(105-86 ))*(x - 864))+ 150 
    elif x <= 200:
        return ((100/(200-106 ))*(x - 106))+ 200 
    elif x > 200:
        return 0
    else:
        return 0

df["03_SubIndex"] = df["Ozone_8hr_avg"].apply(lambda x: get_03_subindex(x))

# %%
print(df["ozone"].max())
print(df["Ozone_8hr_avg"].max())
print(df["03_SubIndex"].max())
# Out:
# 80.0
# 71.25
# 100.89285714285714

# %%
## CO Sub-Index calculation
def get_CO_subindex(x):
    if x <= 4.4:
        return ((50/4.4)* x)
    elif x <= 9.4:
        return ((50/(9.4-4.5 ))*(x - 4.5))+ 50 
    elif x <= 12.4:
        return ((50/(12.4-9.5))*(x - 9.5))+ 100 
    elif x <= 15.4:
        return ((50/(15.4- 12.5 ))*(x - 12.5))+ 150 
    elif x <= 30.4:
        return ((100/(30.4- 15.5 ))*(x - 15.5))+ 200 
    elif x <= 40.4:
        return ((100/(40.4- 30.5))*(x - 30.5))+ 300 
    elif x >50.4:
        return ((100/(50.4-40.4))*(x - 40.4))+ 400 
    else:
        return 0

df["CO_SubIndex"] = df["CO_8hr_avg"].apply(lambda x: get_CO_subindex(x))

# %%
print(df["CO"].max())
print(df["CO_8hr_avg"].max())
print(df["CO_SubIndex"].max())
# Out:
# 2.9755
# 2.1618749999999998
# 24.56676136363636

# %%
#SO2 Subindex 

def get_SO2_subindex(x):
    if x <= 35:
        return ((50/35)* x)
    elif x <= 75:
        return ((50/(75-36))*(x - 36))+ 50 
    elif x <= 185:
        return (((50/(185-76))*(x - 76)))+ 100 
    elif x <= 304:
        return ((50/(304-186))*(x - 186))+ 150 
    elif x <= 604:
        return ((100/(604-305))*(x - 305))+ 200 
    elif x <= 804:
        return ((100/(804-605))*(x - 605))+ 300 
    elif x >1004:
        return ((100/(1004-805))*(x - 805))+ 400 
    else:
        return 0

df["SO2_SubIndex"] = df["SO2"].apply(lambda x: get_SO2_subindex(x))

# %%
print(df["SO2"].max())
print(df["SO2_SubIndex"].max())
# Out:
# 104.6
# 113.11926605504587

# %%
#NO2 Subindex 

def get_NO2_subindex(x):
    if x <= 53:
        return ((50/53)* x)
    elif x <= 100:
        return ((50/(100-54))*(x - 54))+ 50 
    elif x <= 360:
        return (((50/(360-101))*(x - 101)))+ 100 
    elif x <= 649:
        return ((50/(649-361))*(x - 361))+ 150 
    elif x <= 1249:
        return ((100/(1249-650))*(x - 650))+ 200 
    elif x <= 1649:
        return ((100/(1649-1250))*(x - 1250))+ 300 
    elif x >2049:
        return ((100/(2049-1650))*(x - 1650))+ 400 
    else:
        return 0

df["NO2_SubIndex"] = df["NO2"].apply(lambda x: get_NO2_subindex(x))
df["NO2_CAPS_SubIndex"] = df["NO2_caps"].apply(lambda x: get_NO2_subindex(x))

# %%
print(df["NO2"].max())
print(df["NO2_SubIndex"].max())
# Out:
# 106.12
# 100.98841698841699

# %%
print(df["NO2_caps"].max())
print(df["NO2_CAPS_SubIndex"].max())
# Out:
# 69.27
# 66.59782608695652

# %%
list(df.columns)
# Out:
# ['Site',
#  'Date',
#  'CO',
#  'NO2',
#  'NO2_caps',
#  'ozone',
#  'PM2.5_MO',
#  'PM2.5_FEM',
#  'RH',
#  'SO2',
#  'Temperature',
#  'Temperature_10_m',
#  'Wind_Direction_s',
#  'Wind_Direction_v',
#  'Wind_Speed_p',
#  'Wind_Speed_s',
#  'DOY',
#  'Ozone_8hr_avg',
#  'PM2.5_MO_24hr_avg',
#  'PM2.5_FEM_24hr_avg',
#  'CO_8hr_avg',
#  'PM2.5MO_SubIndex',
#  'PM2.5FEM_SubIndex',
#  'PM2.5_1hrMO_SubIndex',
#  'PM2.5_1hrFEM_SubIndex',
#  '03_SubIndex',
#  'CO_SubIndex',
#  'SO2_SubIndex',
#  'NO2_SubIndex',
#  'NO2_CAPS_SubIndex']

# %%
def get_AQI_bucket(x):
    if x <= 50:
        return "Good"
    elif x <= 100:
        return "Satisfactory"
    elif x <= 200:
        return "Moderate"
    elif x <= 300:
        return "Poor"
    elif x <= 400:
        return "Very Poor"
    elif x > 400:
        return "Severe"
    else:
        return np.NaN

# %%
#df["AQI_calculated"] = round(df[["PM2.5MO_SubIndex", "PM2.5FEM_SubIndex", "03_SubIndex", "CO_SubIndex",'SO2_SubIndex',
#                                 "NO2_SubIndex", "NO2_CAPS_SubIndex", 'PM2.5_1hrMO_SubIndex', 'PM2.5_1hrFEM_SubIndex']].max(axis = 1))

df["AQI_calculated"] = round(df[["PM2.5MO_SubIndex", "PM2.5FEM_SubIndex", "03_SubIndex", "CO_SubIndex",'SO2_SubIndex',
                                 "NO2_SubIndex", "NO2_CAPS_SubIndex"]].max(axis = 1))

df["AQI_calculated_where"] = df[["PM2.5MO_SubIndex", "PM2.5FEM_SubIndex", "03_SubIndex", "CO_SubIndex",'SO2_SubIndex',
                                 "NO2_SubIndex", "NO2_CAPS_SubIndex"]].idxmax(axis=1)
df['AQI_Cause'] = df['AQI_calculated_where'].map({'PM2.5MO_SubIndex': 'PM2.5', 'PM2.5FEM_SubIndex': 'PM2.5',
                                                                "03_SubIndex": 'O3', "CO_SubIndex": "CO", 'SO2_SubIndex':'SO2', 
                                                                   "NO2_SubIndex": "NO2","NO2_CAPS_SubIndex": "NO2" })
df
# Out:
#                         Site                Date      CO  NO2  NO2_caps  \
# 73522    Seattle Beacon Hill 2012-01-01 00:00:00     NaN  NaN       NaN
# 73533    Seattle Beacon Hill 2012-01-01 01:00:00     NaN  NaN       NaN
# 73538    Seattle Beacon Hill 2012-01-01 02:00:00     NaN  NaN       NaN
# 73539    Seattle Beacon Hill 2012-01-01 03:00:00     NaN  NaN       NaN
# 73540    Seattle Beacon Hill 2012-01-01 04:00:00     NaN  NaN       NaN
# ...                      ...                 ...     ...  ...       ...
# 13828  Seattle 10th & Weller 2022-11-14 12:00:00  0.2451  9.0       NaN
# 13829  Seattle 10th & Weller 2022-11-14 13:00:00  0.2136  8.5       NaN
# 91419    Seattle Beacon Hill 2022-11-14 13:00:00  0.2129  NaN      8.10
# 91420    Seattle Beacon Hill 2022-11-14 14:00:00  0.1864  NaN      6.18
# 13830  Seattle 10th & Weller 2022-11-14 14:00:00  0.2365  7.6       NaN
#
#        ozone  PM2.5_MO  PM2.5_FEM    RH  SO2  ...  PM2.5_1hrFEM_SubIndex  \
# 73522   10.0       NaN       10.3  71.0  NaN  ...              42.916667
# 73533   30.0       NaN        3.0  64.0  NaN  ...              12.500000
# 73538   30.0       NaN        2.3  65.0  NaN  ...               9.583333
# 73539   30.0       NaN        NaN  66.0  NaN  ...               0.000000
# 73540   20.0       NaN        3.5  67.0  NaN  ...              14.583333
# ...      ...       ...        ...   ...  ...  ...                    ...
# 13828    NaN      13.0        NaN   NaN  NaN  ...               0.000000
# 13829    NaN       9.0        NaN   NaN  NaN  ...               0.000000
# 91419   20.0       6.0        NaN   NaN  0.3  ...               0.000000
# 91420   20.0       7.0        NaN   NaN  0.2  ...               0.000000
# 13830    NaN       7.0        NaN   NaN  NaN  ...               0.000000
#
#        03_SubIndex  CO_SubIndex  SO2_SubIndex  NO2_SubIndex  \
# 73522     0.000000     0.000000      0.000000      0.000000
# 73533     0.000000     0.000000      0.000000      0.000000
# 73538     0.000000     0.000000      0.000000      0.000000
# 73539     0.000000     0.000000      0.000000      0.000000
# 73540     0.000000     0.000000      0.000000      0.000000
# ...            ...          ...           ...           ...
# 13828     9.259259     2.456108      0.000000      8.490566
# 13829     9.259259     2.557955      0.000000      8.018868
# 91419     9.259259     2.609233      0.428571      0.000000
# 91420    10.416667     2.609517      0.285714      0.000000
# 13830    11.574074     2.556676      0.000000      7.169811
#
#        NO2_CAPS_SubIndex AQI_calculated  AQI_bucket_calculated  \
# 73522           0.000000            0.0                   Good
# 73533           0.000000            0.0                   Good
# 73538           0.000000            0.0                   Good
# 73539           0.000000            0.0                   Good
# 73540           0.000000            0.0                   Good
# ...                  ...            ...                    ...
# 13828           0.000000           49.0                   Good
# 13829           0.000000           49.0                   Good
# 91419           7.641509           50.0                   Good
# 91420           5.830189           50.0                   Good
# 13830           0.000000           50.0                   Good
#
#        AQI_calculated_where  AQI_Cause
# 73522      PM2.5MO_SubIndex      PM2.5
# 73533      PM2.5MO_SubIndex      PM2.5
# 73538      PM2.5MO_SubIndex      PM2.5
# 73539      PM2.5MO_SubIndex      PM2.5
# 73540      PM2.5MO_SubIndex      PM2.5
# ...                     ...        ...
# 13828      PM2.5MO_SubIndex      PM2.5
# 13829      PM2.5MO_SubIndex      PM2.5
# 91419      PM2.5MO_SubIndex      PM2.5
# 91420      PM2.5MO_SubIndex      PM2.5
# 13830      PM2.5MO_SubIndex      PM2.5
#
# [167597 rows x 34 columns]

# %%
df["AQI_bucket_calculated"] = df["AQI_calculated"].apply(lambda x: get_AQI_bucket(x))
df[~df.AQI_calculated.isna()].AQI_bucket_calculated.value_counts()

df
# Out:
#                         Site                Date      CO  NO2  NO2_caps  \
# 73522    Seattle Beacon Hill 2012-01-01 00:00:00     NaN  NaN       NaN
# 73533    Seattle Beacon Hill 2012-01-01 01:00:00     NaN  NaN       NaN
# 73538    Seattle Beacon Hill 2012-01-01 02:00:00     NaN  NaN       NaN
# 73539    Seattle Beacon Hill 2012-01-01 03:00:00     NaN  NaN       NaN
# 73540    Seattle Beacon Hill 2012-01-01 04:00:00     NaN  NaN       NaN
# ...                      ...                 ...     ...  ...       ...
# 13828  Seattle 10th & Weller 2022-11-14 12:00:00  0.2451  9.0       NaN
# 13829  Seattle 10th & Weller 2022-11-14 13:00:00  0.2136  8.5       NaN
# 91419    Seattle Beacon Hill 2022-11-14 13:00:00  0.2129  NaN      8.10
# 91420    Seattle Beacon Hill 2022-11-14 14:00:00  0.1864  NaN      6.18
# 13830  Seattle 10th & Weller 2022-11-14 14:00:00  0.2365  7.6       NaN
#
#        ozone  PM2.5_MO  PM2.5_FEM    RH  SO2  ...  PM2.5_1hrMO_SubIndex  \
# 73522   10.0       NaN       10.3  71.0  NaN  ...              0.000000
# 73533   30.0       NaN        3.0  64.0  NaN  ...              0.000000
# 73538   30.0       NaN        2.3  65.0  NaN  ...              0.000000
# 73539   30.0       NaN        NaN  66.0  NaN  ...              0.000000
# 73540   20.0       NaN        3.5  67.0  NaN  ...              0.000000
# ...      ...       ...        ...   ...  ...  ...                   ...
# 13828    NaN      13.0        NaN   NaN  NaN  ...             51.931330
# 13829    NaN       9.0        NaN   NaN  NaN  ...             37.500000
# 91419   20.0       6.0        NaN   NaN  0.3  ...             25.000000
# 91420   20.0       7.0        NaN   NaN  0.2  ...             29.166667
# 13830    NaN       7.0        NaN   NaN  NaN  ...             29.166667
#
#        PM2.5_1hrFEM_SubIndex  03_SubIndex  CO_SubIndex  SO2_SubIndex  \
# 73522              42.916667     0.000000     0.000000      0.000000
# 73533              12.500000     0.000000     0.000000      0.000000
# 73538               9.583333     0.000000     0.000000      0.000000
# 73539               0.000000     0.000000     0.000000      0.000000
# 73540              14.583333     0.000000     0.000000      0.000000
# ...                      ...          ...          ...           ...
# 13828               0.000000     9.259259     2.456108      0.000000
# 13829               0.000000     9.259259     2.557955      0.000000
# 91419               0.000000     9.259259     2.609233      0.428571
# 91420               0.000000    10.416667     2.609517      0.285714
# 13830               0.000000    11.574074     2.556676      0.000000
#
#        NO2_SubIndex NO2_CAPS_SubIndex  AQI_calculated  AQI_bucket_calculated  \
# 73522      0.000000          0.000000             0.0                   Good
# 73533      0.000000          0.000000             0.0                   Good
# 73538      0.000000          0.000000             0.0                   Good
# 73539      0.000000          0.000000             0.0                   Good
# 73540      0.000000          0.000000             0.0                   Good
# ...             ...               ...             ...                    ...
# 13828      8.490566          0.000000            49.0                   Good
# 13829      8.018868          0.000000            49.0                   Good
# 91419      0.000000          7.641509            50.0                   Good
# 91420      0.000000          5.830189            50.0                   Good
# 13830      7.169811          0.000000            50.0                   Good
#
#        AQI_calculated_where
# 73522      PM2.5MO_SubIndex
# 73533      PM2.5MO_SubIndex
# 73538      PM2.5MO_SubIndex
# 73539      PM2.5MO_SubIndex
# 73540      PM2.5MO_SubIndex
# ...                     ...
# 13828      PM2.5MO_SubIndex
# 13829      PM2.5MO_SubIndex
# 91419      PM2.5MO_SubIndex
# 91420      PM2.5MO_SubIndex
# 13830      PM2.5MO_SubIndex
#
# [167597 rows x 33 columns]

# %%
percip= pd.read_csv("Data/percip2.csv", sep=',')
percip.Date =pd.to_datetime(percip.Date)

percip.head()
percip.shape

df5 = pd.merge(df, percip, how="left", on=["Date"])
df5.shape
df3 = pd.merge(df5, result, how="left", on=["Date"])

# %%
# Make a daily DF

dfD= df.groupby(['Site']).resample('D', on=('Date')).mean()
dfD= dfD.reset_index()
daily_AQI= pd.merge(dfD, daily, how="left", on=["Date"])
daily_AQI

percipD= percip.resample('D', on='Date').sum()
percipD= percipD.reset_index()
percipD


daily_AQI_P= pd.merge(daily_AQI, percipD, how="left", on=["Date"])

daily_AQI_P["AQI_bucket_calculated"] = daily_AQI_P["AQI_calculated"].apply(lambda x: get_AQI_bucket(x))
daily_AQI_P["AQI_calculated_where"] = daily_AQI_P[["PM2.5MO_SubIndex", "PM2.5FEM_SubIndex", "03_SubIndex", "CO_SubIndex",'SO2_SubIndex',
                                 "NO2_SubIndex", "NO2_CAPS_SubIndex"]].idxmax(axis=1)


print(daily_AQI_P[~daily_AQI_P.AQI_calculated.isna()].AQI_bucket_calculated.value_counts())

daily_AQI_P

daily_AQI_P = daily_AQI_P[daily_AQI_P['AQI_calculated'].notna()]
daily_AQI_P.describe() 
#daily_AQI_P.to_csv('Data/Daily_Bike_AQI_Weather.csv')
list(daily_AQI_P.columns)


daily_AQI_P['AQI_Cause'] = daily_AQI_P['AQI_calculated_where'].map({'PM2.5MO_SubIndex': 'PM2.5', 'PM2.5FEM_SubIndex': 'PM2.5',
                                                                "03_SubIndex": 'O3', "CO_SubIndex": "CO", 'SO2_SubIndex':'SO2', 
                                                                 "NO2_SubIndex": "NO2","NO2_CAPS_SubIndex": "NO2" })
daily_AQI_P
#daily_AQI_P.to_csv('Data/Daily_Bike_AQI_Weather.csv')
# Out:
# Good            6487
# Satisfactory     467
# Moderate          57
# Poor               6
# Name: AQI_bucket_calculated, dtype: int64

# %%
mask = daily_AQI_P[daily_AQI_P['AQI_bucket_calculated'] == 'Poor']
mask
# Out:
#                        Site       Date        CO        NO2   NO2_caps  \
# 739   Seattle 10th & Weller 2016-05-29  0.249138   9.099583        NaN
# 740   Seattle 10th & Weller 2016-05-30  0.297025   9.030000        NaN
# 2704  Seattle 10th & Weller 2021-10-15  0.443017  18.413043        NaN
# 4710    Seattle Beacon Hill 2016-05-29  0.150600        NaN        NaN
# 4711    Seattle Beacon Hill 2016-05-30  0.174008        NaN        NaN
# 6675    Seattle Beacon Hill 2021-10-15  0.208387        NaN  12.053636
#
#           ozone  PM2.5_MO  PM2.5_FEM         RH       SO2  ...  \
# 739         NaN       NaN   3.620833        NaN       NaN  ...
# 740         NaN       NaN   5.033333        NaN       NaN  ...
# 2704        NaN  7.208333        NaN        NaN       NaN  ...
# 4710  33.750000       NaN   3.133333  81.083333  0.212500  ...
# 4711  31.739130       NaN   5.483333  63.375000  0.308696  ...
# 6675  22.916667  4.652174        NaN  80.416667  0.354167  ...
#
#       Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk  \
# 739                          427.0                         472.0
# 740                         1534.0                        1431.0
# 2704                         738.0                        1120.0
# 4710                         427.0                         472.0
# 4711                        1534.0                        1431.0
# 6675                         738.0                        1120.0
#
#       Spokane St. Bridge Total   West   East  time_hour  time_yr  DOW  \
# 739                      287.0  153.0  134.0        0.0   2016.0  6.0
# 740                     1100.0  537.0  563.0        0.0   2016.0  0.0
# 2704                     748.0  367.0  381.0        0.0   2021.0  4.0
# 4710                     287.0  153.0  134.0        0.0   2016.0  6.0
# 4711                    1100.0  537.0  563.0        0.0   2016.0  0.0
# 6675                     748.0  367.0  381.0        0.0   2021.0  4.0
#
#       precip_accum_one_hour_set_1  AQI_bucket_calculated
# 739                      1.183333                   Poor
# 740                      0.000000                   Poor
# 2704                     2.221905                   Poor
# 4710                     1.183333                   Poor
# 4711                     0.000000                   Poor
# 6675                     2.221905                   Poor
#
# [6 rows x 42 columns]

# %%
list(daily_AQI_P.columns.unique())
# Out:
# ['Site',
#  'Date',
#  'CO',
#  'NO2',
#  'NO2_caps',
#  'ozone',
#  'PM2.5_MO',
#  'PM2.5_FEM',
#  'RH',
#  'SO2',
#  'Temperature',
#  'Temperature_10_m',
#  'Wind_Direction_s',
#  'Wind_Direction_v',
#  'Wind_Speed_p',
#  'Wind_Speed_s',
#  'Temperatue',
#  'Ozone_8hr_avg',
#  'PM2.5_MO_24hr_avg',
#  'PM2.5_FEM_24hr_avg',
#  'CO_8hr_avg',
#  'PM2.5MO_SubIndex',
#  'PM2.5FEM_SubIndex',
#  'PM2.5_1hrMO_SubIndex',
#  'PM2.5_1hrFEM_SubIndex',
#  '03_SubIndex',
#  'CO_SubIndex',
#  'SO2_SubIndex',
#  'NO2_SubIndex',
#  'NO2_CAPS_SubIndex',
#  'AQI_calculated',
#  'Fremont Bridge Total',
#  'Fremont Bridge East Sidewalk',
#  'Fremont Bridge West Sidewalk',
#  'Spokane St. Bridge Total',
#  'West',
#  'East',
#  'time_hour',
#  'time_yr',
#  'DOW',
#  'precip_accum_one_hour_set_1',
#  'AQI_bucket_calculated']

# %%
print(df3.shape)
#df3.to_csv('Data/Bike_AQI_Weather.csv', sep=',', index=False)
df3
# Out:
# (167597, 41)
#                          Site                Date      CO  NO2  NO2_caps  \
# 0         Seattle Beacon Hill 2012-01-01 00:00:00     NaN  NaN       NaN
# 1         Seattle Beacon Hill 2012-01-01 01:00:00     NaN  NaN       NaN
# 2         Seattle Beacon Hill 2012-01-01 02:00:00     NaN  NaN       NaN
# 3         Seattle Beacon Hill 2012-01-01 03:00:00     NaN  NaN       NaN
# 4         Seattle Beacon Hill 2012-01-01 04:00:00     NaN  NaN       NaN
# ...                       ...                 ...     ...  ...       ...
# 167592  Seattle 10th & Weller 2022-11-14 12:00:00  0.2451  9.0       NaN
# 167593  Seattle 10th & Weller 2022-11-14 13:00:00  0.2136  8.5       NaN
# 167594    Seattle Beacon Hill 2022-11-14 13:00:00  0.2129  NaN      8.10
# 167595    Seattle Beacon Hill 2022-11-14 14:00:00  0.1864  NaN      6.18
# 167596  Seattle 10th & Weller 2022-11-14 14:00:00  0.2365  7.6       NaN
#
#         ozone  PM2.5_MO  PM2.5_FEM    RH  SO2  ...  AQI_bucket_calculated  \
# 0        10.0       NaN       10.3  71.0  NaN  ...                   Good
# 1        30.0       NaN        3.0  64.0  NaN  ...                   Good
# 2        30.0       NaN        2.3  65.0  NaN  ...                   Good
# 3        30.0       NaN        NaN  66.0  NaN  ...                   Good
# 4        20.0       NaN        3.5  67.0  NaN  ...                   Good
# ...       ...       ...        ...   ...  ...  ...                    ...
# 167592    NaN      13.0        NaN   NaN  NaN  ...                   Good
# 167593    NaN       9.0        NaN   NaN  NaN  ...                   Good
# 167594   20.0       6.0        NaN   NaN  0.3  ...                   Good
# 167595   20.0       7.0        NaN   NaN  0.2  ...                   Good
# 167596    NaN       7.0        NaN   NaN  NaN  ...                   Good
#
#         AQI_calculated_where  AQI_Cause  precip_accum_one_hour_set_1  \
# 0           PM2.5MO_SubIndex      PM2.5                          NaN
# 1           PM2.5MO_SubIndex      PM2.5                          NaN
# 2           PM2.5MO_SubIndex      PM2.5                          NaN
# 3           PM2.5MO_SubIndex      PM2.5                          NaN
# 4           PM2.5MO_SubIndex      PM2.5                          NaN
# ...                      ...        ...                          ...
# 167592      PM2.5MO_SubIndex      PM2.5                          NaN
# 167593      PM2.5MO_SubIndex      PM2.5                          NaN
# 167594      PM2.5MO_SubIndex      PM2.5                          NaN
# 167595      PM2.5MO_SubIndex      PM2.5                          NaN
# 167596      PM2.5MO_SubIndex      PM2.5                          NaN
#
#         Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
# ...                      ...                           ...
# 167592                   NaN                           NaN
# 167593                   NaN                           NaN
# 167594                   NaN                           NaN
# 167595                   NaN                           NaN
# 167596                   NaN                           NaN
#
#        Fremont Bridge West Sidewalk  Spokane St. Bridge Total  West  East
# 0                               NaN                       NaN   NaN   NaN
# 1                               NaN                       NaN   NaN   NaN
# 2                               NaN                       NaN   NaN   NaN
# 3                               NaN                       NaN   NaN   NaN
# 4                               NaN                       NaN   NaN   NaN
# ...                             ...                       ...   ...   ...
# 167592                          NaN                       NaN   NaN   NaN
# 167593                          NaN                       NaN   NaN   NaN
# 167594                          NaN                       NaN   NaN   NaN
# 167595                          NaN                       NaN   NaN   NaN
# 167596                          NaN                       NaN   NaN   NaN
#
# [167597 rows x 41 columns]

# %%
#mask = df[df['AQI_bucket_calculated'] == 'Satisfactory']
mask = df3[df3['AQI_bucket_calculated'] != 'Good']
#worse = df3[df3['AQI_calculated'] <= 100]
#worse
mask = df3[df3['AQI_bucket_calculated'] == 'Moderate']
#mask.to_csv('mask.csv')
mask['AQI_bucket_calculated'].unique()
# Out:
# array(['Moderate'], dtype=object)

# %%
worse = df3[df3['AQI_calculated'] >= 101]
print(worse['AQI_bucket_calculated'].unique())
worse
#worse.to_csv('Data/AQIG100.csv', index = False)
# Out:
# ['Moderate' 'Poor']

# %%
poor = df3[df3['AQI_bucket_calculated'] == 'Poor']
#poor.to_csv('Data/poorAQI.csv', index = False)

#poor
# Out:
#                          Site                Date      CO    NO2  NO2_caps  \
# 54527   Seattle 10th & Weller 2016-05-28 12:00:00  0.3680  10.15       NaN
# 54528     Seattle Beacon Hill 2016-05-28 12:00:00  0.1509    NaN       NaN
# 54529   Seattle 10th & Weller 2016-05-28 13:00:00  0.3807  11.02       NaN
# 54530     Seattle Beacon Hill 2016-05-28 13:00:00  0.1570    NaN       NaN
# 54559     Seattle Beacon Hill 2016-05-29 04:00:00  0.1312    NaN       NaN
# ...                       ...                 ...     ...    ...       ...
# 148703    Seattle Beacon Hill 2021-10-15 21:00:00  0.2439    NaN     14.69
# 148704  Seattle 10th & Weller 2021-10-15 22:00:00  0.4074  11.00       NaN
# 148705    Seattle Beacon Hill 2021-10-15 22:00:00  0.2256    NaN     12.29
# 148706  Seattle 10th & Weller 2021-10-15 23:00:00  0.5548  14.80       NaN
# 148707    Seattle Beacon Hill 2021-10-15 23:00:00  0.2275    NaN     11.66
#
#         ozone  PM2.5_MO  PM2.5_FEM    RH  SO2  ...  AQI_bucket_calculated  \
# 54527     NaN       NaN        6.5   NaN  NaN  ...                   Poor
# 54528    30.0       NaN        2.1  62.0  0.3  ...                   Poor
# 54529     NaN       NaN        3.0   NaN  NaN  ...                   Poor
# 54530    30.0       NaN        1.1  66.0  0.3  ...                   Poor
# 54559    30.0       NaN        2.9  94.0  0.2  ...                   Poor
# ...       ...       ...        ...   ...  ...  ...                    ...
# 148703   20.0       5.0        NaN  71.0  0.4  ...                   Poor
# 148704    NaN       8.0        NaN   NaN  NaN  ...                   Poor
# 148705   20.0       8.0        NaN  72.0  0.4  ...                   Poor
# 148706    NaN      10.0        NaN   NaN  NaN  ...                   Poor
# 148707   20.0       8.0        NaN  76.0  0.4  ...                   Poor
#
#         AQI_calculated_where  AQI_Cause  precip_accum_one_hour_set_1  \
# 54527       PM2.5MO_SubIndex      PM2.5                         0.25
# 54528       PM2.5MO_SubIndex      PM2.5                         0.25
# 54529       PM2.5MO_SubIndex      PM2.5                         0.51
# 54530       PM2.5MO_SubIndex      PM2.5                         0.51
# 54559       PM2.5MO_SubIndex      PM2.5                          NaN
# ...                      ...        ...                          ...
# 148703      PM2.5MO_SubIndex      PM2.5                          NaN
# 148704      PM2.5MO_SubIndex      PM2.5                          NaN
# 148705      PM2.5MO_SubIndex      PM2.5                          NaN
# 148706      PM2.5MO_SubIndex      PM2.5                          NaN
# 148707      PM2.5MO_SubIndex      PM2.5                          NaN
#
#         Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# 54527                  116.0                          55.0
# 54528                  116.0                          55.0
# 54529                   94.0                          56.0
# 54530                   94.0                          56.0
# 54559                    0.0                           0.0
# ...                      ...                           ...
# 148703                  35.0                          13.0
# 148704                  26.0                          13.0
# 148705                  26.0                          13.0
# 148706                  23.0                          15.0
# 148707                  23.0                          15.0
#
#        Fremont Bridge West Sidewalk  Spokane St. Bridge Total  West  East
# 54527                          61.0                      37.0  13.0  24.0
# 54528                          61.0                      37.0  13.0  24.0
# 54529                          38.0                      28.0  14.0  14.0
# 54530                          38.0                      28.0  14.0  14.0
# 54559                           0.0                       4.0   2.0   2.0
# ...                             ...                       ...   ...   ...
# 148703                         22.0                      12.0   9.0   3.0
# 148704                         13.0                      11.0   9.0   2.0
# 148705                         13.0                      11.0   9.0   2.0
# 148706                          8.0                       7.0   6.0   1.0
# 148707                          8.0                       7.0   6.0   1.0
#
# [126 rows x 41 columns]

# %%
list(mask.columns)
# Out:
# ['Site',
#  'Date',
#  'CO',
#  'NO2',
#  'NO2_caps',
#  'ozone',
#  'PM2.5_MO',
#  'PM2.5_FEM',
#  'RH',
#  'SO2',
#  'Temperature',
#  'Temperature_10_m',
#  'Wind_Direction_s',
#  'Wind_Direction_v',
#  'Wind_Speed_p',
#  'Wind_Speed_s',
#  'DOY',
#  'Temperatue',
#  'Ozone_8hr_avg',
#  'PM2.5_MO_24hr_avg',
#  'PM2.5_FEM_24hr_avg',
#  'CO_8hr_avg',
#  'PM2.5MO_SubIndex',
#  'PM2.5FEM_SubIndex',
#  'PM2.5_1hrMO_SubIndex',
#  'PM2.5_1hrFEM_SubIndex',
#  '03_SubIndex',
#  'CO_SubIndex',
#  'SO2_SubIndex',
#  'NO2_SubIndex',
#  'NO2_CAPS_SubIndex',
#  'AQI_calculated',
#  'AQI_bucket_calculated',
#  'precip_accum_one_hour_set_1',
#  'Fremont Bridge Total',
#  'Fremont Bridge East Sidewalk',
#  'Fremont Bridge West Sidewalk',
#  'Spokane St. Bridge Total',
#  'West',
#  'East',
#  'time_hour',
#  'time_yr',
#  'DOW',
#  'time_mn']

# %%
import seaborn as sns
fg = sns.FacetGrid(data=mask, hue='Site', aspect=1.6)
fg.map(plt.scatter, 'time_mn', 'AQI_calculated').add_legend();

# %%
import seaborn as sns
fg = sns.FacetGrid(data=df3, hue='Site', aspect=1.61)
fg.map(plt.scatter, 'Date', 'AQI_calculated').add_legend();

# %%
import seaborn as sns
fg = sns.FacetGrid(data=poor, hue='Site', aspect=1.61)
fg.map(plt.scatter, 'Date', 'AQI_calculated').add_legend();

# %%
fig, (ax1) = plt.subplots(nrows=1, ncols=1, figsize=(8,6))

x1 = mask['Date']
y1 = mask['AQI_calculated']


ax1.scatter(x1, y1, label = "Months where AQI is over 50");


ax1.legend(loc='upper left');

# %%
fig, (ax1) = plt.subplots(nrows=1, ncols=1, figsize=(8,6))

x1 = df['Date']
y1 = df['PM2.5MO_SubIndex']
y2 = df['03_SubIndex']
y3 = df['CO_SubIndex']
y4 = df['SO2_SubIndex']


#ax1.plot(x1, y1, label = "PM 2.5 AQI", color='c', markerfacecolor='white');
#ax1.plot(x1, y2, label = "O3 AQI", color='dodgerblue', markerfacecolor='white');
#ax1.plot(x1, y3, label = "CO AQI", color='m', markerfacecolor='white');
ax1.plot(x1, y4, label = "SO2 AQI", color='lightgreen', markerfacecolor='white');


ax1.legend(loc='upper left');

# %%
fig, (ax1) = plt.subplots(nrows=1, ncols=1, figsize=(8,6))

x1 = df['Date']
y1 = df['PM2.5_MO']
y2 = df['ozone']
y3 = df['CO']
y4 = df['SO2']


ax1.plot(x1, y1, label = "PM 2.5", color='c', markerfacecolor='white');
ax1.plot(x1, y2, label = "O3", color='dodgerblue', markerfacecolor='white');
ax1.plot(x1, y3, label = "CO", color='m', markerfacecolor='white');
ax1.plot(x1, y4, label = "SO2", color='lightgreen', markerfacecolor='white');


ax1.legend(loc='upper left');

# %%
list(df3.columns)
# Out:
# ['Site',
#  'Date',
#  'CO',
#  'NO2',
#  'NO2_caps',
#  'ozone',
#  'PM2.5_MO',
#  'PM2.5_FEM',
#  'RH',
#  'SO2',
#  'Temperature',
#  'Temperature_10_m',
#  'Wind_Direction_s',
#  'Wind_Direction_v',
#  'Wind_Speed_p',
#  'Wind_Speed_s',
#  'DOY',
#  'Temperatue',
#  'Ozone_8hr_avg',
#  'PM2.5_MO_24hr_avg',
#  'PM2.5_FEM_24hr_avg',
#  'CO_8hr_avg',
#  'PM2.5MO_SubIndex',
#  'PM2.5FEM_SubIndex',
#  'PM2.5_1hrMO_SubIndex',
#  'PM2.5_1hrFEM_SubIndex',
#  '03_SubIndex',
#  'CO_SubIndex',
#  'SO2_SubIndex',
#  'NO2_SubIndex',
#  'NO2_CAPS_SubIndex',
#  'AQI_calculated',
#  'AQI_bucket_calculated',
#  'precip_accum_one_hour_set_1',
#  'Fremont Bridge Total',
#  'Fremont Bridge East Sidewalk',
#  'Fremont Bridge West Sidewalk',
#  'Spokane St. Bridge Total',
#  'West',
#  'East',
#  'time_hour',
#  'time_yr',
#  'DOW',
#  'time_mn']

# %%
df3
# Out:
#                          Site                Date      CO  NO2  NO2_caps  \
# 0         Seattle Beacon Hill 2012-01-01 00:00:00     NaN  NaN       NaN
# 1         Seattle Beacon Hill 2012-01-01 01:00:00     NaN  NaN       NaN
# 2         Seattle Beacon Hill 2012-01-01 02:00:00     NaN  NaN       NaN
# 3         Seattle Beacon Hill 2012-01-01 03:00:00     NaN  NaN       NaN
# 4         Seattle Beacon Hill 2012-01-01 04:00:00     NaN  NaN       NaN
# ...                       ...                 ...     ...  ...       ...
# 167592  Seattle 10th & Weller 2022-11-14 12:00:00  0.2451  9.0       NaN
# 167593  Seattle 10th & Weller 2022-11-14 13:00:00  0.2136  8.5       NaN
# 167594    Seattle Beacon Hill 2022-11-14 13:00:00  0.2129  NaN      8.10
# 167595    Seattle Beacon Hill 2022-11-14 14:00:00  0.1864  NaN      6.18
# 167596  Seattle 10th & Weller 2022-11-14 14:00:00  0.2365  7.6       NaN
#
#         ozone  PM2.5_MO  PM2.5_FEM    RH  SO2  ...  Fremont Bridge Total  \
# 0        10.0       NaN       10.3  71.0  NaN  ...                   NaN
# 1        30.0       NaN        3.0  64.0  NaN  ...                   NaN
# 2        30.0       NaN        2.3  65.0  NaN  ...                   NaN
# 3        30.0       NaN        NaN  66.0  NaN  ...                   NaN
# 4        20.0       NaN        3.5  67.0  NaN  ...                   NaN
# ...       ...       ...        ...   ...  ...  ...                   ...
# 167592    NaN      13.0        NaN   NaN  NaN  ...                   NaN
# 167593    NaN       9.0        NaN   NaN  NaN  ...                   NaN
# 167594   20.0       6.0        NaN   NaN  0.3  ...                   NaN
# 167595   20.0       7.0        NaN   NaN  0.2  ...                   NaN
# 167596    NaN       7.0        NaN   NaN  NaN  ...                   NaN
#
#         Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# ...                              ...                           ...
# 167592                           NaN                           NaN
# 167593                           NaN                           NaN
# 167594                           NaN                           NaN
# 167595                           NaN                           NaN
# 167596                           NaN                           NaN
#
#         Spokane St. Bridge Total  West  East time_hour  time_yr  DOW  time_mn
# 0                            NaN   NaN   NaN       NaN      NaN  NaN      NaN
# 1                            NaN   NaN   NaN       NaN      NaN  NaN      NaN
# 2                            NaN   NaN   NaN       NaN      NaN  NaN      NaN
# 3                            NaN   NaN   NaN       NaN      NaN  NaN      NaN
# 4                            NaN   NaN   NaN       NaN      NaN  NaN      NaN
# ...                          ...   ...   ...       ...      ...  ...      ...
# 167592                       NaN   NaN   NaN       NaN      NaN  NaN      NaN
# 167593                       NaN   NaN   NaN       NaN      NaN  NaN      NaN
# 167594                       NaN   NaN   NaN       NaN      NaN  NaN      NaN
# 167595                       NaN   NaN   NaN       NaN      NaN  NaN      NaN
# 167596                       NaN   NaN   NaN       NaN      NaN  NaN      NaN
#
# [167597 rows x 44 columns]

# %% [markdown]
# ## TS Analysis

# %%
plt.plot(df3.Date, df3['Spokane St. Bridge Total'])
plt.title('Spokane St. Bridge Total')
plt.ylabel('Hourly Bike Counts');
plt.show()

plt.plot(df3.Date, df3['Fremont Bridge Total'], 'lightgreen')
plt.title('Fremont Bridge Total')
plt.ylabel('Hourly Bike Counts');
plt.show()

# %%
plt.plot(df3.Date, df3['Fremont Bridge Total'], 'dodgerblue', label="Freemont")
plt.plot(df3.Date, df3['Spokane St. Bridge Total'], 'lightgreen', label= "Spokane Street")
plt.title('Hourly Bike Counts')
plt.ylabel('Hourly Bike Counts');
plt.legend();
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
df_new= df3[['Date', 'Fremont Bridge Total']]
df_new= df_new.set_index('Date')

# %%
df_new['SMA_24'] = df_new['Fremont Bridge Total'].rolling(24, min_periods=20).mean()
df_new['SMA_168'] = df_new['Fremont Bridge Total'].rolling(168, min_periods=150).mean()
df_new['SMA_8760'] = df_new['Fremont Bridge Total'].rolling(8760, min_periods=7000).mean()
df_new
# Out:
#                      Fremont Bridge Total  SMA_24  SMA_168  SMA_8760
# Date
# 2012-01-01 00:00:00                   NaN     NaN      NaN       NaN
# 2012-01-01 01:00:00                   NaN     NaN      NaN       NaN
# 2012-01-01 02:00:00                   NaN     NaN      NaN       NaN
# 2012-01-01 03:00:00                   NaN     NaN      NaN       NaN
# 2012-01-01 04:00:00                   NaN     NaN      NaN       NaN
# ...                                   ...     ...      ...       ...
# 2022-11-14 12:00:00                   NaN     NaN      NaN       NaN
# 2022-11-14 13:00:00                   NaN     NaN      NaN       NaN
# 2022-11-14 13:00:00                   NaN     NaN      NaN       NaN
# 2022-11-14 14:00:00                   NaN     NaN      NaN       NaN
# 2022-11-14 14:00:00                   NaN     NaN      NaN       NaN
#
# [167597 rows x 4 columns]

# %%
# Grean = Avg Air Temp, RED = 10 yrs, ORANG colors for the line plot
colors = ['green', 'red', 'orange', 'dodgerblue']
# Line plot 
df_new.plot(color=colors, linewidth=3, figsize=(12,6))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(labels =['Freemont Total', '24 SMA', '168 SMA', '8670 SMA'], fontsize=14)
plt.title('SMA on Freemont', fontsize=20);
plt.xlabel('Year', fontsize=16)
plt.ylabel('Bike Counts', fontsize=16);

#https://www.analyticsvidhya.com/blog/2021/10/a-comprehensive-guide-to-time-series-analysis/

# %% [markdown]
# # Air Quality from Beacon and 10th and Weller Station

# %% [markdown]
# aq= pd.read_csv("Data/AW_DataDownload_11_14_22.csv", sep=',')
# aq

# %% [markdown]
# ## Outdoor weather observations recorded at Seattle-Tacoma International Airport:
# https://download.synopticdata.com/#a/KSEA

# %% [markdown]
# #out= pd.read_csv("Data/KSEA.csv", sep=',', header=[10])
# out= pd.read_csv("Data/KSEA.2022-11-21.csv", sep=',', header=[10])
#
# out.head()

# %% [markdown]
# out.describe()

# %% [markdown]
# list(out.columns)

# %% [markdown]
# out= out.drop(0,axis=0)

# %% [markdown]
# out.Date_Time= pd.to_datetime(out.Date_Time)
#
# cols = out.columns.drop(['Date_Time'])
#
# out[cols] = out[cols].apply(pd.to_numeric, errors='coerce')
#
# out.head(5)

# %% [markdown]
# percip= out [['Date_Time', 'precip_accum_one_hour_set_1']]
# #percip.to_csv('Data/percip.csv')

# %% [markdown]
# out.info()

# %% [markdown]
# fig,ax = plt.subplots(figsize=(18,10))
#
# ax.set_title('Hourly Cumulative Percipitation')
#
# out.plot(x='Date_Time', y='precip_accum_one_hour_set_1',color='k', markerfacecolor='white', ax=ax)
#
# ax.set_xlabel("Time",fontsize=14)
#
# ax.set_ylabel("Hourly Cumulative Percipitation",color='k',fontsize=14);
#
# #UWASH.plot(x='Date_Time', y='relative_humidity_set_1', color='dodgerblue', marker='*', markerfacecolor='white', ax=ax2)
#
# #ax2.set_ylabel("Hourly Relative Humidity (%)",fontsize=14, color='dodgerblue');
# #ax2.get_legend().remove()
# #ax.get_legend().remove()
# #ax2.invert_yaxis()
# #ax2.set_ylim(-20,30)
#
# #plt.show();

# %% [markdown]
# #df24 =df.set_index('Date').groupby("Site").resample('1D')['PM2.5_MO'].sum(min_count=20)
# #df24.reset_index()
#
# #need to rename the 24 hr merge column and do for
#
#
# fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=4, ncols=1, figsize=(16,17))
#
# x1 = out['Date_Time']
# y1 = out['air_temp_set_1']
#
# ax1.plot(x1, y1, label = "Air Temperature", color='c', markerfacecolor='white')
#
#
#
# #Axis Labels
# ax1.set_ylabel('Air Temperature (F)')
#
#
# x2 = out['Date_Time']
# y2 = out['relative_humidity_set_1']
#
# ax2.plot(x2, y2, label = "RH", color='m',  markerfacecolor='white')
#
# #Axis Labels
# ax2.set_ylabel('RH ')
#
#
# x3 = out['Date_Time']
# y3 = out['air_temp_low_24_hour_set_1']
#
# ax3.plot(x3, y3, label = "Air Temperature Low (F)", color='dodgerblue', markerfacecolor='white')
#
#
# #Axis Labels
# ax3.set_ylabel('Wind Speed (m/s)')
# #ax3.set_xlabel('Date')
# #ax3.set_title('Monthy Degre Day at Pirbadet')
# # show a legend on the plot
#
# ax2.legend(loc='lower right')
#
#
# ax1.legend(loc='lower right')
# ax3.legend(loc='lower right')
#
#
# x4 = out['Date_Time']
# y4 = out['precip_accum_one_hour_set_1']
#
# ax4.plot(x4, y4, label = "Hourly Accumulative Percipitation", color='g',  markerfacecolor='white')
# #axs.set_xlim(pd.Timestamp('2007-12-01 00:00'), pd.Timestamp('2022-05-01 00:00'))
# #ax4.set_xlim(pd.Timestamp('2014-11-01 00:00'), pd.Timestamp('2022-05-01 00:00'))
#
#
# #Axis Labels
# ax4.set_ylabel('Percipitation (mm)')
# ax4.set_xlabel('Date')
#
#
# # show a legend on the plot
#
# ax4.legend(loc='lower right')
#
# # Display a figure.
# plt.show()
