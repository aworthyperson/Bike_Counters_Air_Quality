# %% [markdown]
# #### Analysis in R for the bike project! (first notebook wasn't great)
#
#
#
# By Amanda Worthy

# %%
#library(corrplot)
library(data.table)
library(lubridate)
library(ggplot2)
library(reshape2)
library(scales)
library(zoo)
library(plyr)
library(readr)
library(stats)
library(quantmod)
library(dplyr)
library(readxl)
library(ggplot2)
library(tidyverse)
library(data.table)
library(lubridate)
library(ggplot2)
library(reshape2)
library(scales)
library(zoo)
library(plyr)
library(readr)
library(lubridate)
library(reshape2)
library(scales)
library(broom)
invisible(1:13) # hides it
library(repr)
library(tibble)

options(repr.plot.width=8, repr.plot.height=6) #controls plot size in jupyter
# Out:
# Attaching package: ‘lubridate’
#
# The following objects are masked from ‘package:data.table’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# The following object is masked from ‘package:base’:
#
#     date
#
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
#
# Attaching package: ‘reshape2’
#
# The following objects are masked from ‘package:data.table’:
#
#     dcast, melt
#
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Attaching package: ‘plyr’
#
# The following object is masked from ‘package:lubridate’:
#
#     here
#
#
# Attaching package: ‘readr’
#
# The following object is masked from ‘package:scales’:
#
#     col_factor
#
# Loading required package: xts
# Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
#
# Attaching package: ‘xts’
#
# The following objects are masked from ‘package:data.table’:
#
#     first, last
#
# Loading required package: TTR
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# Version 0.4-0 included new data defaults. See ?getSymbols.
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:xts’:
#
#     first, last
#
# The following objects are masked from ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
# The following objects are masked from ‘package:lubridate’:
#
#     intersect, setdiff, union
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ tibble  2.1.1     ✔ purrr   0.3.2
# ✔ tidyr   0.8.3     ✔ stringr 1.4.0
# ✔ tibble  2.1.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::arrange()         masks plyr::arrange()
# ✖ lubridate::as.difftime() masks base::as.difftime()
# ✖ dplyr::between()         masks data.table::between()
# ✖ readr::col_factor()      masks scales::col_factor()
# ✖ purrr::compact()         masks plyr::compact()
# ✖ dplyr::count()           masks plyr::count()
# ✖ lubridate::date()        masks base::date()
# ✖ purrr::discard()         masks scales::discard()
# ✖ dplyr::failwith()        masks plyr::failwith()
# ✖ dplyr::filter()          masks stats::filter()
# ✖ dplyr::first()           masks xts::first(), data.table::first()
# ✖ plyr::here()             masks lubridate::here()
# ✖ lubridate::hour()        masks data.table::hour()
# ✖ dplyr::id()              masks plyr::id()
# ✖ lubridate::intersect()   masks base::intersect()
# ✖ lubridate::isoweek()     masks data.table::isoweek()
# ✖ dplyr::lag()             masks stats::lag()
# ✖ dplyr::last()            masks xts::last(), data.table::last()
# ✖ lubridate::mday()        masks data.table::mday()
# ✖ lubridate::minute()      masks data.table::minute()
# ✖ lubridate::month()       masks data.table::month()
# ✖ dplyr::mutate()          masks plyr::mutate()
# ✖ lubridate::quarter()     masks data.table::quarter()
# ✖ dplyr::rename()          masks plyr::rename()
# ✖ lubridate::second()      masks data.table::second()
# ✖ lubridate::setdiff()     masks base::setdiff()
# ✖ dplyr::summarise()       masks plyr::summarise()
# ✖ dplyr::summarize()       masks plyr::summarize()
# ✖ purrr::transpose()       masks data.table::transpose()
# ✖ lubridate::union()       masks base::union()
# ✖ lubridate::wday()        masks data.table::wday()
# ✖ lubridate::week()        masks data.table::week()
# ✖ lubridate::yday()        masks data.table::yday()
# ✖ lubridate::year()        masks data.table::year()

# %%
#import dataset 
df<- read.csv("Data/Bike_AQI_Weather.csv")
head(df)
colnames(df)

df$Date= as.Date(df$Date)
df$DOY= as.Date(df$DOY)
# Out:
#   Site                Date                CO NO2 NO2_caps ozone PM2.5_MO
# 1 Seattle Beacon Hill 2012-01-01 00:00:00 NA NA  NA       10    NA
# 2 Seattle Beacon Hill 2012-01-01 01:00:00 NA NA  NA       30    NA
# 3 Seattle Beacon Hill 2012-01-01 02:00:00 NA NA  NA       30    NA
# 4 Seattle Beacon Hill 2012-01-01 03:00:00 NA NA  NA       30    NA
# 5 Seattle Beacon Hill 2012-01-01 04:00:00 NA NA  NA       20    NA
# 6 Seattle Beacon Hill 2012-01-01 05:00:00 NA NA  NA       30    NA
#   PM2.5_FEM RH SO2 ... AQI_bucket_calculated AQI_calculated_where AQI_Cause
# 1 10.3      71 NA  ... Good                  PM2.5MO_SubIndex     PM2.5
# 2  3.0      64 NA  ... Good                  PM2.5MO_SubIndex     PM2.5
# 3  2.3      65 NA  ... Good                  PM2.5MO_SubIndex     PM2.5
# 4   NA      66 NA  ... Good                  PM2.5MO_SubIndex     PM2.5
# 5  3.5      67 NA  ... Good                  PM2.5MO_SubIndex     PM2.5
# 6  2.3      66 NA  ... Good                  PM2.5MO_SubIndex     PM2.5
#   precip_accum_one_hour_set_1 Fremont.Bridge.Total Fremont.Bridge.East.Sidewalk
# 1 NA                          NA                   NA
# 2 NA                          NA                   NA
# 3 NA                          NA                   NA
# 4 NA                          NA                   NA
# 5 NA                          NA                   NA
# 6 NA                          NA                   NA
#   Fremont.Bridge.West.Sidewalk Spokane.St..Bridge.Total West East
# 1 NA                           NA                       NA   NA
# 2 NA                           NA                       NA   NA
# 3 NA                           NA                       NA   NA
# 4 NA                           NA                       NA   NA
# 5 NA                           NA                       NA   NA
# 6 NA                           NA                       NA   NA
#  [1] "Site"                         "Date"
#  [3] "CO"                           "NO2"
#  [5] "NO2_caps"                     "ozone"
#  [7] "PM2.5_MO"                     "PM2.5_FEM"
#  [9] "RH"                           "SO2"
# [11] "Temperature"                  "Temperature_10_m"
# [13] "Wind_Direction_s"             "Wind_Direction_v"
# [15] "Wind_Speed_p"                 "Wind_Speed_s"
# [17] "DOY"                          "Ozone_8hr_avg"
# [19] "PM2.5_MO_24hr_avg"            "PM2.5_FEM_24hr_avg"
# [21] "CO_8hr_avg"                   "PM2.5MO_SubIndex"
# [23] "PM2.5FEM_SubIndex"            "PM2.5_1hrMO_SubIndex"
# [25] "PM2.5_1hrFEM_SubIndex"        "X03_SubIndex"
# [27] "CO_SubIndex"                  "SO2_SubIndex"
# [29] "NO2_SubIndex"                 "NO2_CAPS_SubIndex"
# [31] "AQI_calculated"               "AQI_bucket_calculated"
# [33] "AQI_calculated_where"         "AQI_Cause"
# [35] "precip_accum_one_hour_set_1"  "Fremont.Bridge.Total"
# [37] "Fremont.Bridge.East.Sidewalk" "Fremont.Bridge.West.Sidewalk"
# [39] "Spokane.St..Bridge.Total"     "West"
# [41] "East"

# %%
options(repr.plot.width=7, repr.plot.height=4)

neworder <- c("Good","Satisfactory","Moderate", "Poor")
library(plyr)  ## or dplyr (transform -> mutate)
df <- arrange(transform(df,
             AQI_bucket_calculated=factor(AQI_bucket_calculated,levels=neworder)),AQI_bucket_calculated)

ggplot(df, aes(x=AQI_bucket_calculated, fill=AQI_Cause))  + 
    geom_bar(position="dodge") +
    xlab('Hourly AQI Index Category\n calcualted from both monitoring stations') +
    ylab('Count') +
    guides(fill=guide_legend(title="Pollutant forcing AQI"))
# Out:
# plot without title

# %%
head((df)[36])
# Out:
#   Fremont.Bridge.Total
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %%
names(df)[36] <- "Fremont_Total"
names(df)[37] <- "Fremont_East"
names(df)[38] <- "Fremont_West"
names(df)[39] <- "Spokane_Total"
names(df)[40] <- "Spokane_West"
names(df)[41] <- "Spokane_East"
head(df)
# Out:
#   Site                Date       CO NO2 NO2_caps ozone PM2.5_MO PM2.5_FEM RH
# 1 Seattle Beacon Hill 2012-01-01 NA NA  NA       10    NA       10.3      71
# 2 Seattle Beacon Hill 2012-01-01 NA NA  NA       30    NA        3.0      64
# 3 Seattle Beacon Hill 2012-01-01 NA NA  NA       30    NA        2.3      65
# 4 Seattle Beacon Hill 2012-01-01 NA NA  NA       30    NA         NA      66
# 5 Seattle Beacon Hill 2012-01-01 NA NA  NA       20    NA        3.5      67
# 6 Seattle Beacon Hill 2012-01-01 NA NA  NA       30    NA        2.3      66
#   SO2 ... AQI_bucket_calculated AQI_calculated_where AQI_Cause
# 1 NA  ... Good                  PM2.5MO_SubIndex     PM2.5
# 2 NA  ... Good                  PM2.5MO_SubIndex     PM2.5
# 3 NA  ... Good                  PM2.5MO_SubIndex     PM2.5
# 4 NA  ... Good                  PM2.5MO_SubIndex     PM2.5
# 5 NA  ... Good                  PM2.5MO_SubIndex     PM2.5
# 6 NA  ... Good                  PM2.5MO_SubIndex     PM2.5
#   precip_accum_one_hour_set_1 Fremont_Total Fremont_East Fremont_West
# 1 NA                          NA            NA           NA
# 2 NA                          NA            NA           NA
# 3 NA                          NA            NA           NA
# 4 NA                          NA            NA           NA
# 5 NA                          NA            NA           NA
# 6 NA                          NA            NA           NA
#   Spokane_Total Spokane_West Spokane_East
# 1 NA            NA           NA
# 2 NA            NA           NA
# 3 NA            NA           NA
# 4 NA            NA           NA
# 5 NA            NA           NA
# 6 NA            NA           NA

# %%
#write.csv(df, 'Data/To_Liz.csv', row.names = FALSE)

# %%
library(lubridate)
library(data.table)

# %%
#import dataset 
dfD<- read.csv("Data/Daily_Bike_AQI_Weather.csv")
#head(dfD)

dfD$Date= as.Date(dfD$Date)

beaconD <-subset(dfD, Site == 'Seattle Beacon Hill')
beaconD= beaconD %>% select_if(~ !all(is.na(.)))
head(beaconD)
colnames(beaconD)

neworder <- c("Good","Satisfactory","Moderate", "Poor")
library(plyr)  ## or dplyr (transform -> mutate)

beaconD2 <- arrange(transform(beaconD,
             AQI_bucket_calculated=factor(AQI_bucket_calculated,levels=neworder)),AQI_bucket_calculated)
# Out:
#      X    Site                Date       CO NO2_caps ozone    PM2.5_MO
# 3084 3100 Seattle Beacon Hill 2012-01-01 NA NA       16.25000 NA
# 3085 3101 Seattle Beacon Hill 2012-01-02 NA NA       20.55556 NA
# 3086 3102 Seattle Beacon Hill 2012-01-03 NA NA       16.42857 NA
# 3087 3103 Seattle Beacon Hill 2012-01-04 NA NA       16.11111 NA
# 3088 3104 Seattle Beacon Hill 2012-01-05 NA NA       24.16667 NA
# 3089 3105 Seattle Beacon Hill 2012-01-06 NA NA       11.25000 NA
#      PM2.5_FEM RH       SO2 ... Fremont.Bridge.Total
# 3084 6.350000  60.62500 NA  ... NA
# 3085 5.076471  69.91667 NA  ... NA
# 3086 4.600000  83.95833 NA  ... NA
# 3087 4.935294  86.29167 NA  ... NA
# 3088 4.508333  82.87500 NA  ... NA
# 3089 6.025000  90.54167 NA  ... NA
#      Fremont.Bridge.East.Sidewalk Fremont.Bridge.West.Sidewalk
# 3084 NA                           NA
# 3085 NA                           NA
# 3086 NA                           NA
# 3087 NA                           NA
# 3088 NA                           NA
# 3089 NA                           NA
#      Spokane.St..Bridge.Total West East precip_accum_one_hour_set_1
# 3084 NA                       NA   NA    0.12000
# 3085 NA                       NA   NA    0.25000
# 3086 NA                       NA   NA   10.49500
# 3087 NA                       NA   NA   14.98833
# 3088 NA                       NA   NA    5.62000
# 3089 NA                       NA   NA    0.75000
#      AQI_bucket_calculated AQI_calculated_where AQI_Cause
# 3084 Good                  PM2.5FEM_SubIndex    PM2.5
# 3085 Good                  PM2.5FEM_SubIndex    PM2.5
# 3086 Good                  PM2.5FEM_SubIndex    PM2.5
# 3087 Good                  PM2.5FEM_SubIndex    PM2.5
# 3088 Good                  PM2.5FEM_SubIndex    PM2.5
# 3089 Good                  PM2.5FEM_SubIndex    PM2.5
#  [1] "X"                            "Site"
#  [3] "Date"                         "CO"
#  [5] "NO2_caps"                     "ozone"
#  [7] "PM2.5_MO"                     "PM2.5_FEM"
#  [9] "RH"                           "SO2"
# [11] "Temperature"                  "Temperature_10_m"
# [13] "Wind_Direction_s"             "Wind_Direction_v"
# [15] "Wind_Speed_p"                 "Wind_Speed_s"
# [17] "Ozone_8hr_avg"                "PM2.5_MO_24hr_avg"
# [19] "PM2.5_FEM_24hr_avg"           "CO_8hr_avg"
# [21] "PM2.5MO_SubIndex"             "PM2.5FEM_SubIndex"
# [23] "PM2.5_1hrMO_SubIndex"         "PM2.5_1hrFEM_SubIndex"
# [25] "X03_SubIndex"                 "CO_SubIndex"
# [27] "SO2_SubIndex"                 "NO2_SubIndex"
# [29] "NO2_CAPS_SubIndex"            "AQI_calculated"
# [31] "Fremont.Bridge.Total"         "Fremont.Bridge.East.Sidewalk"
# [33] "Fremont.Bridge.West.Sidewalk" "Spokane.St..Bridge.Total"
# [35] "West"                         "East"
# [37] "precip_accum_one_hour_set_1"  "AQI_bucket_calculated"
# [39] "AQI_calculated_where"         "AQI_Cause"

# %%
#unique(beaconD2$AQI_calculated)
max(beaconD2$AQI_calculated)
# Out:
# [1] 224.9583

# %%
ggplot(beaconD2, aes(x = Date, y = Spokane.St..Bridge.Total, color = AQI_bucket_calculated)) +
     #geom_line(size = 1)+
geom_area(aes(fill=AQI_bucket_calculated), position = 'stack') +
ylab('Spokane Street Bridge Daily Bike Counts') +
    xlab('Date') +
    guides(color=guide_legend(title="AQI Index Category"))
# Out:
# Warning message:
# “Removed 873 rows containing missing values (position_stack).”
# plot without title

# %%
#Use FEM for Beacon

beacon <-subset(df, Site == 'Seattle Beacon Hill')
beacon= beacon %>% select_if(~ !all(is.na(.)))
head(beacon)
# Out:
#   Site                Date       CO NO2_caps ozone PM2.5_MO PM2.5_FEM RH SO2
# 1 Seattle Beacon Hill 2012-01-01 NA NA       10    NA       10.3      71 NA
# 2 Seattle Beacon Hill 2012-01-01 NA NA       30    NA        3.0      64 NA
# 3 Seattle Beacon Hill 2012-01-01 NA NA       30    NA        2.3      65 NA
# 4 Seattle Beacon Hill 2012-01-01 NA NA       30    NA         NA      66 NA
# 5 Seattle Beacon Hill 2012-01-01 NA NA       20    NA        3.5      67 NA
# 6 Seattle Beacon Hill 2012-01-01 NA NA       30    NA        2.3      66 NA
#   Temperature ... NO2_CAPS_SubIndex AQI_calculated AQI_bucket_calculated
# 1 40          ... 0                 0              Good
# 2 42          ... 0                 0              Good
# 3 42          ... 0                 0              Good
# 4 41          ... 0                 0              Good
# 5 41          ... 0                 0              Good
# 6 41          ... 0                 0              Good
#   precip_accum_one_hour_set_1 Fremont_Total Fremont_East Fremont_West
# 1 NA                          NA            NA           NA
# 2 NA                          NA            NA           NA
# 3 NA                          NA            NA           NA
# 4 NA                          NA            NA           NA
# 5 NA                          NA            NA           NA
# 6 NA                          NA            NA           NA
#   Spokane_Total Spokane_West Spokane_East
# 1 NA            NA           NA
# 2 NA            NA           NA
# 3 NA            NA           NA
# 4 NA            NA           NA
# 5 NA            NA           NA
# 6 NA            NA           NA

# %%
okay_beacon <-subset(beacon, AQI_bucket_calculated != 'Good')

# %%
neworder <- c("Good","Satisfactory","Moderate", "Poor")
library(plyr)  ## or dplyr (transform -> mutate)
beacon2 <- arrange(transform(beacon,
             AQI_bucket_calculated=factor(AQI_bucket_calculated,levels=neworder)),AQI_bucket_calculated)

# %%
options(repr.plot.width=7, repr.plot.height=5)

ggplot(beaconD2, aes(x = Date, y = Spokane.St..Bridge.Total, color = AQI_bucket_calculated)) +
    geom_area(aes(fill=AQI_bucket_calculated))+
     #geom_point(size = 1.5)+
    facet_wrap(~ AQI_bucket_calculated, ncol=1)+
    theme_bw()+
    ylab('Spokane Street Bridge Hourly Bike Counts') +
    xlab('Date') +
    #guides(color=guide_legend(title="AQI Index Category"))+
    theme_bw()
# Out:
# Warning message:
# “Removed 873 rows containing missing values (position_stack).”
# plot without title

# %%
#beaconD2[order(beaconD2$Date),]


s= ggplot(beaconD2, aes(y=Spokane.St..Bridge.Total, x=reorder(format(beaconD2$Date,'%b'), beaconD2$Date), fill=AQI_bucket_calculated)) +
  geom_boxplot(position = position_dodge(width = 0.7)) +
  #geom_point(position = position_jitterdodge(seed = 123))+
  ylab('Spokane Street Bridge Daily Bike Counts') +
    scale_x_discrete(limits = month.abb)+
    xlab('Month')+
 theme_classic()+guides(fill=guide_legend(title="AQI Bucket"))


s


#png("boxplotAQ.png")
# Out:
# Warning message:
# “Removed 873 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
beaconD2$weekday <- weekdays(beaconD2$Date) 
beaconD2$weekday= strftime(beaconD2$Date, "%a")

beaconD2$DOW <- wday(beaconD2$Date)

beaconD2
# Out:
#      X    Site                Date       CO        NO2_caps  ozone    PM2.5_MO
# 1    3100 Seattle Beacon Hill 2012-01-01 NA        NA        16.25000 NA
# 2    3101 Seattle Beacon Hill 2012-01-02 NA        NA        20.55556 NA
# 3    3102 Seattle Beacon Hill 2012-01-03 NA        NA        16.42857 NA
# 4    3103 Seattle Beacon Hill 2012-01-04 NA        NA        16.11111 NA
# 5    3104 Seattle Beacon Hill 2012-01-05 NA        NA        24.16667 NA
# 6    3105 Seattle Beacon Hill 2012-01-06 NA        NA        11.25000 NA
# 7    3106 Seattle Beacon Hill 2012-01-07 NA        NA        10.00000 NA
# 8    3107 Seattle Beacon Hill 2012-01-08 NA        NA        10.00000 NA
# 9    3108 Seattle Beacon Hill 2012-01-09 NA        NA        17.14286 NA
# 10   3109 Seattle Beacon Hill 2012-01-10 NA        NA        19.04762 NA
# 11   3110 Seattle Beacon Hill 2012-01-11 NA        NA        13.12500 NA
# 12   3112 Seattle Beacon Hill 2012-01-13 NA        NA              NA NA
# 13   3113 Seattle Beacon Hill 2012-01-14 NA        NA        24.37500 NA
# 14   3114 Seattle Beacon Hill 2012-01-15 NA        NA        18.75000 NA
# 15   3115 Seattle Beacon Hill 2012-01-16 NA        NA        17.22222 NA
# 16   3116 Seattle Beacon Hill 2012-01-17 NA        NA        21.25000 NA
# 17   3117 Seattle Beacon Hill 2012-01-18 NA        NA        26.95652 NA
# 18   3118 Seattle Beacon Hill 2012-01-19 NA        NA        18.75000 NA
# 19   3119 Seattle Beacon Hill 2012-01-20 NA        NA        20.00000 NA
# 20   3120 Seattle Beacon Hill 2012-01-21 NA        NA        28.75000 NA
# 21   3121 Seattle Beacon Hill 2012-01-22 NA        NA        26.95652 NA
# 22   3122 Seattle Beacon Hill 2012-01-23 NA        NA        16.00000 NA
# 23   3123 Seattle Beacon Hill 2012-01-24 NA        NA        20.00000 NA
# 24   3124 Seattle Beacon Hill 2012-01-25 NA        NA        23.75000 NA
# 25   3125 Seattle Beacon Hill 2012-01-26 NA        NA        24.00000 NA
# 26   3126 Seattle Beacon Hill 2012-01-27 NA        NA        14.61538 NA
# 27   3127 Seattle Beacon Hill 2012-01-28 NA        NA        10.00000 NA
# 28   3128 Seattle Beacon Hill 2012-01-29 NA        NA        20.00000 NA
# 29   3129 Seattle Beacon Hill 2012-01-30 NA        NA        27.72727 NA
# 30   3130 Seattle Beacon Hill 2012-01-31 NA        NA        23.91304 NA
# ...  ...  ...                 ...        ...       ...       ...      ...
# 3905 4110 Seattle Beacon Hill 2014-10-07        NA        NA 11.11111        NA
# 3906 4296 Seattle Beacon Hill 2015-04-11        NA        NA 38.75000        NA
# 3907 4298 Seattle Beacon Hill 2015-04-13        NA        NA 31.57895        NA
# 3908 4299 Seattle Beacon Hill 2015-04-14        NA        NA 31.73913        NA
# 3909 4300 Seattle Beacon Hill 2015-04-15        NA        NA 30.83333        NA
# 3910 4301 Seattle Beacon Hill 2015-04-16        NA        NA 25.23810        NA
# 3911 4708 Seattle Beacon Hill 2016-05-27 0.1583500        NA 32.50000        NA
# 3912 4709 Seattle Beacon Hill 2016-05-28 0.1681435        NA 27.39130        NA
# 3913 4712 Seattle Beacon Hill 2016-05-31 0.2207739        NA 27.91667        NA
# 3914 5091 Seattle Beacon Hill 2017-06-14 0.1395522        NA 31.30435        NA
# 3915 5093 Seattle Beacon Hill 2017-06-16 0.1267043        NA 23.04348        NA
# 3916 5094 Seattle Beacon Hill 2017-06-17 0.1510217        NA 23.33333        NA
# 3917 6106 Seattle Beacon Hill 2020-03-25 0.1922583  9.030833 24.58333  3.000000
# 3918 6107 Seattle Beacon Hill 2020-03-26 0.1863833  6.679583 31.73913  4.875000
# 3919 6109 Seattle Beacon Hill 2020-03-28 0.1781750  4.459167 30.83333  1.733333
# 3920 6110 Seattle Beacon Hill 2020-03-29 0.1327667  1.955833 33.91304  2.416667
# 3921 6295 Seattle Beacon Hill 2020-09-30 0.4566292 23.566522       NA  9.125000
# 3922 6297 Seattle Beacon Hill 2020-10-02 0.3873500 19.446667 10.00000 12.416667
# 3923 6298 Seattle Beacon Hill 2020-10-03 0.3168708 13.423333 10.00000  9.166667
# 3924 6299 Seattle Beacon Hill 2020-10-04 0.3013125 16.171739 10.76923  4.583333
# 3925 6300 Seattle Beacon Hill 2020-10-05 0.2573318 12.445833 13.33333  8.291667
# 3926 6673 Seattle Beacon Hill 2021-10-13 0.2540375 13.721250 17.14286  6.708333
# 3927 6674 Seattle Beacon Hill 2021-10-14 0.1936739  8.637083 21.81818  4.100000
# 3928 6676 Seattle Beacon Hill 2021-10-16 0.1890125  6.390417 27.08333  4.875000
# 3929 7055 Seattle Beacon Hill 2022-10-30 0.1407478  4.884091 28.26087  5.291667
# 3930 7057 Seattle Beacon Hill 2022-11-01 0.1957292  9.390417 19.54545  5.952381
# 3931 7058 Seattle Beacon Hill 2022-11-02 0.2184792 13.119583 19.56522  5.625000
# 3932 4710 Seattle Beacon Hill 2016-05-29 0.1506000        NA 33.75000        NA
# 3933 4711 Seattle Beacon Hill 2016-05-30 0.1740083        NA 31.73913        NA
# 3934 6675 Seattle Beacon Hill 2021-10-15 0.2083875 12.053636 22.91667  4.652174
#      PM2.5_FEM RH       SO2       ... Fremont.Bridge.East.Sidewalk
# 1     6.350000 60.62500 NA        ... NA
# 2     5.076471 69.91667 NA        ... NA
# 3     4.600000 83.95833 NA        ... NA
# 4     4.935294 86.29167 NA        ... NA
# 5     4.508333 82.87500 NA        ... NA
# 6     6.025000 90.54167 NA        ... NA
# 7     5.650000 91.75000 NA        ... NA
# 8     7.541667 82.87500 NA        ... NA
# 9     4.886364 84.75000 NA        ... NA
# 10    3.743750 75.33333 NA        ... NA
# 11    4.927778 73.91667 NA        ... NA
# 12   14.620833 86.66667 NA        ... NA
# 13    6.645833 86.58333 NA        ... NA
# 14    5.500000 94.66667 NA        ... NA
# 15    5.900000 93.87500 NA        ... NA
# 16    2.439130 88.95833 NA        ... NA
# 17    2.660870 96.08333 NA        ... NA
# 18    4.712500 99.04167 NA        ... NA
# 19   16.962500 98.83333 NA        ... NA
# 20    2.550000 86.12500 NA        ... NA
# 21    3.131818 82.91667 NA        ... NA
# 22    6.862500 78.66667 NA        ... NA
# 23    5.666667 89.62500 NA        ... NA
# 24    5.933333 82.66667 NA        ... NA
# 25    3.970833 86.00000 NA        ... NA
# 26    9.070000 82.00000 NA        ... NA
# 27   15.370833 70.95833 NA        ... NA
# 28   10.341667 92.87500 NA        ... NA
# 29    2.591667 88.25000 NA        ... NA
# 30    4.250000 80.58333 NA        ... NA
# ...  ...       ...      ...           ...
# 3905 12.008333 96.29167        NA ... 2211
# 3906  3.291667 77.37500        NA ...  707
# 3907  4.408333 86.12500        NA ... 1165
# 3908  3.479167 87.29167        NA ... 1242
# 3909  3.266667 67.12500        NA ... 1908
# 3910  5.126087 67.52174        NA ... 2080
# 3911  4.436364 72.87500 0.3291667 ... 1401
# 3912  3.958333 85.16667 0.2782609 ...  581
# 3913  6.542857 57.87500 0.7125000 ... 2450
# 3914  2.804167 62.95833 0.2166667 ... 1842
# 3915  2.362500 74.50000 0.3000000 ... 1567
# 3916  4.354167 75.54167 0.1666667 ...  799
# 3917        NA       NA 0.5916667 ...  614
# 3918        NA       NA 0.5428571 ...  566
# 3919        NA       NA 0.5041667 ...  710
# 3920        NA       NA 0.4833333 ... 1438
# 3921        NA 87.08333 1.8958333 ... 1053
# 3922        NA 87.00000 1.4291667 ... 1039
# 3923        NA 98.87500 1.1708333 ...  898
# 3924        NA 94.50000 1.0000000 ...  640
# 3925        NA 87.54167 0.9136364 ...  994
# 3926        NA 88.25000 0.4625000 ...  912
# 3927        NA 91.75000 0.3045455 ...  787
# 3928        NA 71.12500 0.3458333 ...  967
# 3929        NA       NA 0.1800000 ...   NA
# 3930        NA       NA 0.2833333 ...   NA
# 3931        NA       NA 0.2458333 ...   NA
# 3932  3.133333 81.08333 0.2125000 ...  427
# 3933  5.483333 63.37500 0.3086957 ... 1534
# 3934        NA 80.41667 0.3541667 ...  738
#      Fremont.Bridge.West.Sidewalk Spokane.St..Bridge.Total West East
# 1    NA                           NA                       NA   NA
# 2    NA                           NA                       NA   NA
# 3    NA                           NA                       NA   NA
# 4    NA                           NA                       NA   NA
# 5    NA                           NA                       NA   NA
# 6    NA                           NA                       NA   NA
# 7    NA                           NA                       NA   NA
# 8    NA                           NA                       NA   NA
# 9    NA                           NA                       NA   NA
# 10   NA                           NA                       NA   NA
# 11   NA                           NA                       NA   NA
# 12   NA                           NA                       NA   NA
# 13   NA                           NA                       NA   NA
# 14   NA                           NA                       NA   NA
# 15   NA                           NA                       NA   NA
# 16   NA                           NA                       NA   NA
# 17   NA                           NA                       NA   NA
# 18   NA                           NA                       NA   NA
# 19   NA                           NA                       NA   NA
# 20   NA                           NA                       NA   NA
# 21   NA                           NA                       NA   NA
# 22   NA                           NA                       NA   NA
# 23   NA                           NA                       NA   NA
# 24   NA                           NA                       NA   NA
# 25   NA                           NA                       NA   NA
# 26   NA                           NA                       NA   NA
# 27   NA                           NA                       NA   NA
# 28   NA                           NA                       NA   NA
# 29   NA                           NA                       NA   NA
# 30   NA                           NA                       NA   NA
# ...  ...                          ...                      ...  ...
# 3905 1653                         1123                     553  570
# 3906  557                          327                     163  164
# 3907  993                          621                     281  340
# 3908 1182                          627                     315  312
# 3909 1789                          959                     475  484
# 3910 1922                         1077                     528  549
# 3911 1462                          894                     440  454
# 3912  604                          453                     221  232
# 3913 2449                         1551                     779  772
# 3914 2557                         1344                     666  678
# 3915 2098                          947                     487  460
# 3916  910                          714                     363  351
# 3917  776                          438                     216  222
# 3918  612                          456                     220  236
# 3919  748                          415                     204  211
# 3920 1429                         1019                     517  502
# 3921 1477                         1111                     548  563
# 3922 1447                          962                     471  491
# 3923 1122                          727                     344  383
# 3924  888                          519                     251  268
# 3925 1411                          931                     451  480
# 3926 1405                          864                     424  440
# 3927 1276                          816                     402  414
# 3928 1201                          676                     339  337
# 3929   NA                           NA                      NA   NA
# 3930   NA                           NA                      NA   NA
# 3931   NA                           NA                      NA   NA
# 3932  472                          287                     153  134
# 3933 1431                         1100                     537  563
# 3934 1120                          748                     367  381
#      precip_accum_one_hour_set_1 AQI_bucket_calculated AQI_calculated_where
# 1     0.120000                   Good                  PM2.5FEM_SubIndex
# 2     0.250000                   Good                  PM2.5FEM_SubIndex
# 3    10.495000                   Good                  PM2.5FEM_SubIndex
# 4    14.988333                   Good                  PM2.5FEM_SubIndex
# 5     5.620000                   Good                  PM2.5FEM_SubIndex
# 6     0.750000                   Good                  PM2.5FEM_SubIndex
# 7     1.670000                   Good                  PM2.5FEM_SubIndex
# 8     0.000000                   Good                  PM2.5FEM_SubIndex
# 9     0.150000                   Good                  PM2.5FEM_SubIndex
# 10    5.660000                   Good                  PM2.5FEM_SubIndex
# 11    0.000000                   Good                  PM2.5FEM_SubIndex
# 12    0.000000                   Good                  PM2.5FEM_SubIndex
# 13    2.890000                   Good                  PM2.5FEM_SubIndex
# 14    3.410667                   Good                  PM2.5FEM_SubIndex
# 15    0.935000                   Good                  PM2.5FEM_SubIndex
# 16    9.358667                   Good                  PM2.5FEM_SubIndex
# 17   17.810000                   Good                  PM2.5FEM_SubIndex
# 18   24.500000                   Good                  PM2.5FEM_SubIndex
# 19    8.133333                   Good                  PM2.5FEM_SubIndex
# 20    9.830000                   Good                  PM2.5FEM_SubIndex
# 21    3.395000                   Good                  PM2.5FEM_SubIndex
# 22    2.260000                   Good                  PM2.5FEM_SubIndex
# 23    4.120000                   Good                  PM2.5FEM_SubIndex
# 24    7.511667                   Good                  PM2.5FEM_SubIndex
# 25    7.955000                   Good                  PM2.5FEM_SubIndex
# 26    0.000000                   Good                  PM2.5FEM_SubIndex
# 27    0.120000                   Good                  PM2.5FEM_SubIndex
# 28   14.675000                   Good                  PM2.5FEM_SubIndex
# 29   11.795833                   Good                  PM2.5FEM_SubIndex
# 30    0.820000                   Good                  PM2.5FEM_SubIndex
# ...  ...                         ...                   ...
# 3905  0.000000                   Moderate              PM2.5MO_SubIndex
# 3906 10.290000                   Moderate              PM2.5MO_SubIndex
# 3907  1.775000                   Moderate              PM2.5MO_SubIndex
# 3908 13.921667                   Moderate              PM2.5MO_SubIndex
# 3909  0.250000                   Moderate              PM2.5MO_SubIndex
# 3910  0.000000                   Moderate              PM2.5MO_SubIndex
# 3911  0.000000                   Moderate              PM2.5MO_SubIndex
# 3912  1.160000                   Moderate              PM2.5MO_SubIndex
# 3913  0.000000                   Moderate              PM2.5MO_SubIndex
# 3914  0.000000                   Moderate              PM2.5MO_SubIndex
# 3915  9.010148                   Moderate              PM2.5MO_SubIndex
# 3916  0.030000                   Moderate              PM2.5MO_SubIndex
# 3917  5.189167                   Moderate              PM2.5FEM_SubIndex
# 3918  0.000000                   Moderate              PM2.5FEM_SubIndex
# 3919  1.138000                   Moderate              PM2.5FEM_SubIndex
# 3920 14.442550                   Moderate              PM2.5FEM_SubIndex
# 3921  0.000000                   Moderate              PM2.5FEM_SubIndex
# 3922  0.000000                   Moderate              PM2.5FEM_SubIndex
# 3923  0.000000                   Moderate              PM2.5FEM_SubIndex
# 3924  0.000000                   Moderate              PM2.5FEM_SubIndex
# 3925  0.000000                   Moderate              PM2.5FEM_SubIndex
# 3926  2.032680                   Moderate              PM2.5MO_SubIndex
# 3927  1.836048                   Moderate              PM2.5MO_SubIndex
# 3928  0.060000                   Moderate              PM2.5MO_SubIndex
# 3929  0.560000                   Moderate              PM2.5MO_SubIndex
# 3930  0.000000                   Moderate              PM2.5MO_SubIndex
# 3931  3.066250                   Moderate              PM2.5MO_SubIndex
# 3932  1.183333                   Poor                  PM2.5MO_SubIndex
# 3933  0.000000                   Poor                  PM2.5MO_SubIndex
# 3934  2.221905                   Poor                  PM2.5MO_SubIndex
#      weekday DOW
# 1    Sun     1
# 2    Mon     2
# 3    Tue     3
# 4    Wed     4
# 5    Thu     5
# 6    Fri     6
# 7    Sat     7
# 8    Sun     1
# 9    Mon     2
# 10   Tue     3
# 11   Wed     4
# 12   Fri     6
# 13   Sat     7
# 14   Sun     1
# 15   Mon     2
# 16   Tue     3
# 17   Wed     4
# 18   Thu     5
# 19   Fri     6
# 20   Sat     7
# 21   Sun     1
# 22   Mon     2
# 23   Tue     3
# 24   Wed     4
# 25   Thu     5
# 26   Fri     6
# 27   Sat     7
# 28   Sun     1
# 29   Mon     2
# 30   Tue     3
# ...  ...     ...
# 3905 Tue     3
# 3906 Sat     7
# 3907 Mon     2
# 3908 Tue     3
# 3909 Wed     4
# 3910 Thu     5
# 3911 Fri     6
# 3912 Sat     7
# 3913 Tue     3
# 3914 Wed     4
# 3915 Fri     6
# 3916 Sat     7
# 3917 Wed     4
# 3918 Thu     5
# 3919 Sat     7
# 3920 Sun     1
# 3921 Wed     4
# 3922 Fri     6
# 3923 Sat     7
# 3924 Sun     1
# 3925 Mon     2
# 3926 Wed     4
# 3927 Thu     5
# 3928 Sat     7
# 3929 Sun     1
# 3930 Tue     3
# 3931 Wed     4
# 3932 Sun     1
# 3933 Mon     2
# 3934 Fri     6

# %%
options(repr.plot.width=7, repr.plot.height=6) #controls plot size in jupyter


t= ggplot(beaconD2, aes(y=Spokane.St..Bridge.Total,  x=reorder(format(beaconD2$Date,'%b'), beaconD2$Date), fill=AQI_bucket_calculated)) +
  geom_boxplot(position = position_dodge(width = 0.7)) +
  #geom_point(position = position_jitterdodge(seed = 123))+
    ylab('Spokane Street Bridge Daily Bike Counts') +
    xlab('Month of Year')+
scale_x_discrete(limits = month.abb)+
     theme_classic()+guides(fill=guide_legend(title="AQI Bucket"))+
  facet_wrap(~AQI_bucket_calculated,ncol=1 ) 

t
# Out:
# Warning message:
# “Removed 873 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
options(repr.plot.width=7, repr.plot.height=6) #controls plot size in jupyter


t= ggplot(beaconD2, aes(y=Spokane.St..Bridge.Total, x=reorder(format(beaconD2$weekday),beaconD2$DOW), fill=AQI_bucket_calculated)) +
  geom_boxplot(position = position_dodge(width = 0.7)) +
  #geom_point(position = position_jitterdodge(seed = 123))+
    ylab('Spokane Street Bridge Daily Bike Counts') +
    xlab('Day of Week')+
     theme_classic()+guides(fill=guide_legend(title="AQI Bucket"))+
  facet_wrap(~AQI_bucket_calculated,ncol=1 ) 

t
# Out:
# Warning message:
# “Removed 873 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
weller <-subset(df, Site == 'Seattle 10th & Weller')
weller= weller %>% select_if(~ !all(is.na(.)))

head(weller)
# Out:
#       Site                  Date       CO NO2 PM2.5_MO PM2.5_FEM
# 20818 Seattle 10th & Weller 2014-05-21 NA NA  NA       9.1
# 20820 Seattle 10th & Weller 2014-05-22 NA NA  NA       7.5
# 20823 Seattle 10th & Weller 2014-05-22 NA NA  NA       7.3
# 20825 Seattle 10th & Weller 2014-05-22 NA NA  NA       6.9
# 20827 Seattle 10th & Weller 2014-05-22 NA NA  NA       6.4
# 20829 Seattle 10th & Weller 2014-05-22 NA NA  NA       6.9
#       Temperature_10_m Wind_Direction_s Wind_Speed_s DOY        ...
# 20818 NA               NA               NA           2014-05-21 ...
# 20820 NA               NA               NA           2014-05-22 ...
# 20823 NA               NA               NA           2014-05-22 ...
# 20825 NA               NA               NA           2014-05-22 ...
# 20827 NA               NA               NA           2014-05-22 ...
# 20829 NA               NA               NA           2014-05-22 ...
#       NO2_CAPS_SubIndex AQI_calculated AQI_bucket_calculated
# 20818 0                 15             Good
# 20820 0                 13             Good
# 20823 0                 12             Good
# 20825 0                 14             Good
# 20827 0                 16             Good
# 20829 0                 17             Good
#       precip_accum_one_hour_set_1 Fremont_Total Fremont_East Fremont_West
# 20818 NA                          40            18           22
# 20820 NA                          17             9            8
# 20823 NA                           5             3            2
# 20825 NA                           4             3            1
# 20827 NA                           2             0            2
# 20829 NA                           9             6            3
#       Spokane_Total Spokane_West Spokane_East
# 20818 9             7            2
# 20820 6             4            2
# 20823 2             0            2
# 20825 2             2            0
# 20827 2             1            1
# 20829 8             1            7

# %%
neworder <- c("Good","Satisfactory","Moderate", "Poor")
library(plyr)  ## or dplyr (transform -> mutate)
weller2 <- arrange(transform(weller,
             AQI_bucket_calculated=factor(AQI_bucket_calculated,levels=neworder)),AQI_bucket_calculated)

# %%
options(repr.plot.width=7, repr.plot.height=5)

ggplot(weller2, aes(x = Date, y = Fremont_Total, color = AQI_bucket_calculated)) +
     geom_point(size = 1.5) + facet_wrap(~  AQI_bucket_calculated, ncol=1)+
     theme_bw()+
    ylab('Freemont Bridge Hourly Bike Counts') +
    xlab('Date') +
    guides(color=guide_legend(title="AQI Index Category"))+
    theme_bw()
# Out:
# Warning message:
# “Removed 1849 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(weller2, aes(x = Date, y = Fremont_Total, color = AQI_bucket_calculated)) +
     geom_point(size = 1)+
ylab('Freemont Bridge Hourly Bike Counts') +
    xlab('Date') +
    guides(color=guide_legend(title="AQI Index Category"))+
    theme_bw()
# Out:
# Warning message:
# “Removed 1849 rows containing missing values (geom_point).”
# plot without title

# %%
sumB <- summary(beacon)
print(sumB)
# Out:
#                     Site            Date                  CO
#  Seattle 10th & Weller:    0   Min.   :2012-01-01   Min.   :0.01
#  Seattle Beacon Hill  :94075   1st Qu.:2014-09-11   1st Qu.:0.15
#                                Median :2017-06-27   Median :0.19
#                                Mean   :2017-06-15   Mean   :0.22
#                                3rd Qu.:2020-03-07   3rd Qu.:0.24
#                                Max.   :2022-11-14   Max.   :1.79
#                                                     NA's   :35700
#     NO2_caps         ozone          PM2.5_MO       PM2.5_FEM
#  Min.   : 0.42   Min.   :10.00   Min.   :  0.2   Min.   :  0.100
#  1st Qu.: 3.92   1st Qu.:20.00   1st Qu.:  2.0   1st Qu.:  3.200
#  Median : 7.51   Median :20.00   Median :  4.0   Median :  4.900
#  Mean   : 9.86   Mean   :23.86   Mean   :  7.0   Mean   :  6.215
#  3rd Qu.:13.67   3rd Qu.:30.00   3rd Qu.:  7.0   3rd Qu.:  7.600
#  Max.   :69.27   Max.   :80.00   Max.   :943.0   Max.   :145.400
#  NA's   :55067   NA's   :16616   NA's   :72986   NA's   :26665
#        RH              SO2          Temperature    Temperature_10_m
#  Min.   : 11.00   Min.   :  0.10   Min.   :19.00   Min.   :-180.0
#  1st Qu.: 67.00   1st Qu.:  0.30   1st Qu.:44.00   1st Qu.:  45.0
#  Median : 83.00   Median :  0.50   Median :51.00   Median :  53.0
#  Mean   : 79.03   Mean   :  0.64   Mean   :51.98   Mean   :  53.2
#  3rd Qu.: 94.00   3rd Qu.:  0.80   3rd Qu.:59.00   3rd Qu.:  61.0
#  Max.   :269.00   Max.   :104.60   Max.   :89.00   Max.   : 283.0
#  NA's   :6668     NA's   :44090    NA's   :56658   NA's   :37894
#  Wind_Direction_s Wind_Direction_v  Wind_Speed_p    Wind_Speed_s
#  Min.   :  0.0    Min.   :  0.0    Min.   : 0.10   Min.   : 0.60
#  1st Qu.: 98.0    1st Qu.:107.0    1st Qu.: 2.60   1st Qu.: 2.70
#  Median :174.0    Median :175.0    Median : 3.60   Median : 3.70
#  Mean   :173.8    Mean   :172.5    Mean   : 4.05   Mean   : 4.04
#  3rd Qu.:247.0    3rd Qu.:228.0    3rd Qu.: 5.10   3rd Qu.: 5.00
#  Max.   :360.0    Max.   :360.0    Max.   :17.60   Max.   :12.50
#  NA's   :25043    NA's   :76060    NA's   :75986   NA's   :88659
#       DOY             Ozone_8hr_avg   PM2.5_MO_24hr_avg PM2.5_FEM_24hr_avg
#  Min.   :2012-01-01   Min.   :10.00   Min.   :  1.31    Min.   :  0.83
#  1st Qu.:2014-09-11   1st Qu.:17.14   1st Qu.:  4.27    1st Qu.:  4.18
#  Median :2017-06-27   Median :22.86   Median :  5.87    Median :  6.17
#  Mean   :2017-06-15   Mean   :23.59   Mean   :  8.11    Mean   :  7.24
#  3rd Qu.:2020-03-07   3rd Qu.:30.00   3rd Qu.:  8.29    3rd Qu.:  8.88
#  Max.   :2022-11-14   Max.   :71.25   Max.   :189.08    Max.   :106.86
#                       NA's   :53041   NA's   :59404     NA's   :37851
#    CO_8hr_avg    PM2.5MO_SubIndex PM2.5FEM_SubIndex PM2.5_1hrMO_SubIndex
#  Min.   :0.000   Min.   :  0.00   Min.   :  0.00    Min.   :  0.000
#  1st Qu.:0.198   1st Qu.:  0.00   1st Qu.:  0.00    1st Qu.:  0.000
#  Median :0.309   Median :  0.00   Median : 14.83    Median :  0.000
#  Mean   :0.361   Mean   : 10.99   Mean   : 17.34    Mean   :  5.407
#  3rd Qu.:0.466   3rd Qu.: 19.57   3rd Qu.: 28.94    3rd Qu.:  0.000
#  Max.   :2.162   Max.   :238.62   Max.   :177.06    Max.   :796.321
#  NA's   :21404
#  PM2.5_1hrFEM_SubIndex  X03_SubIndex     CO_SubIndex      SO2_SubIndex
#  Min.   :  0.00        Min.   :  0.00   Min.   : 0.000   Min.   :  0.0000
#  1st Qu.:  0.00        1st Qu.:  0.00   1st Qu.: 1.418   1st Qu.:  0.0000
#  Median : 14.58        Median :  0.00   Median : 2.686   Median :  0.1429
#  Mean   : 17.63        Mean   :  9.53   Mean   : 3.166   Mean   :  0.4860
#  3rd Qu.: 26.67        3rd Qu.: 19.68   3rd Qu.: 4.681   3rd Qu.:  0.8571
#  Max.   :197.37        Max.   :100.89   Max.   :24.567   Max.   :113.1193
#
#   NO2_SubIndex NO2_CAPS_SubIndex AQI_calculated    AQI_bucket_calculated
#  Min.   :0     Min.   : 0.000    Min.   :  0.00   Good        :84754
#  1st Qu.:0     1st Qu.: 0.000    1st Qu.: 22.00   Moderate    :  670
#  Median :0     Median : 0.000    Median : 28.00   Poor        :   63
#  Mean   :0     Mean   : 3.855    Mean   : 31.34   Satisfactory: 8588
#  3rd Qu.:0     3rd Qu.: 5.509    3rd Qu.: 37.00
#  Max.   :0     Max.   :66.598    Max.   :239.00
#
#  precip_accum_one_hour_set_1 Fremont_Total     Fremont_East     Fremont_West
#  Min.   : 0.00               Min.   :   0.0   Min.   :  0.00   Min.   :  0.00
#  1st Qu.: 0.03               1st Qu.:  13.0   1st Qu.:  5.00   1st Qu.:  7.00
#  Median : 0.25               Median :  60.0   Median : 27.00   Median : 31.00
#  Mean   : 0.53               Mean   : 108.5   Mean   : 47.61   Mean   : 60.87
#  3rd Qu.: 0.70               3rd Qu.: 146.0   3rd Qu.: 66.00   3rd Qu.: 78.00
#  Max.   :23.25               Max.   :1097.0   Max.   :698.00   Max.   :850.00
#  NA's   :76031               NA's   :19292    NA's   :19292    NA's   :19292
#  Spokane_Total     Spokane_West     Spokane_East
#  Min.   :  0.00   Min.   :  0.00   Min.   :  0.0
#  1st Qu.:  4.00   1st Qu.:  2.00   1st Qu.:  2.0
#  Median : 17.00   Median :  6.00   Median :  7.0
#  Mean   : 32.57   Mean   : 15.93   Mean   : 16.4
#  3rd Qu.: 45.00   3rd Qu.: 17.00   3rd Qu.: 20.0
#  Max.   :431.00   Max.   :367.00   Max.   :330.0
#  NA's   :20577    NA's   :19833    NA's   :19833

# %%
sumW <- summary(weller)
print(sumW)
# Out:
#                     Site            Date                  CO
#  Seattle 10th & Weller:73522   Min.   :2014-05-21   Min.   :0.000
#  Seattle Beacon Hill  :    0   1st Qu.:2016-07-28   1st Qu.:0.278
#                                Median :2018-09-02   Median :0.397
#                                Mean   :2018-08-26   Mean   :0.441
#                                3rd Qu.:2020-10-07   3rd Qu.:0.550
#                                Max.   :2022-11-14   Max.   :2.975
#                                                     NA's   :8565
#       NO2            PM2.5_MO         PM2.5_FEM     Temperature_10_m
#  Min.   :  0.02   Min.   :  1.000   Min.   : 0.10   Min.   : 18.00
#  1st Qu.: 11.62   1st Qu.:  4.000   1st Qu.: 4.80   1st Qu.: 46.00
#  Median : 17.70   Median :  6.000   Median : 7.50   Median : 54.00
#  Mean   : 19.28   Mean   :  8.713   Mean   : 8.65   Mean   : 54.51
#  3rd Qu.: 25.21   3rd Qu.: 10.000   3rd Qu.:11.10   3rd Qu.: 62.00
#  Max.   :106.12   Max.   :282.000   Max.   :55.70   Max.   :108.00
#  NA's   :6489     NA's   :26744     NA's   :49945   NA's   :927
#  Wind_Direction_s  Wind_Speed_s         DOY             Ozone_8hr_avg
#  Min.   :  0.0    Min.   : 0.000   Min.   :2014-05-21   Min.   :10.00
#  1st Qu.: 75.0    1st Qu.: 2.500   1st Qu.:2016-07-28   1st Qu.:17.14
#  Median :187.0    Median : 3.900   Median :2018-09-02   Median :22.86
#  Mean   :168.5    Mean   : 4.413   Mean   :2018-08-26   Mean   :23.57
#  3rd Qu.:237.0    3rd Qu.: 5.600   3rd Qu.:2020-10-07   3rd Qu.:30.00
#  Max.   :360.0    Max.   :23.600   Max.   :2022-11-14   Max.   :70.00
#  NA's   :390      NA's   :390                           NA's   :32421
#  PM2.5_MO_24hr_avg PM2.5_FEM_24hr_avg   CO_8hr_avg    PM2.5MO_SubIndex
#  Min.   :  1.38    Min.   :  0.81     Min.   :0.000   Min.   :  0.00
#  1st Qu.:  4.33    1st Qu.:  3.61     1st Qu.:0.180   1st Qu.:  0.00
#  Median :  5.92    Median :  5.07     Median :0.254   Median :  0.00
#  Mean   :  8.13    Mean   :  6.19     Mean   :0.301   Mean   : 14.26
#  3rd Qu.:  8.42    3rd Qu.:  7.36     3rd Qu.:0.378   3rd Qu.: 23.84
#  Max.   :189.42    Max.   :106.77     Max.   :2.118   Max.   :238.96
#  NA's   :38655     NA's   :37644      NA's   :18294
#  PM2.5FEM_SubIndex PM2.5_1hrMO_SubIndex PM2.5_1hrFEM_SubIndex  X03_SubIndex
#  Min.   :  0.00    Min.   :  0.00       Min.   :  0.00        Min.   :  0.00
#  1st Qu.:  0.00    1st Qu.:  0.00       1st Qu.:  0.00        1st Qu.:  0.00
#  Median :  0.00    Median : 16.67       Median :  0.00        Median : 11.57
#  Mean   : 12.14    Mean   : 20.21       Mean   : 10.84        Mean   : 12.21
#  3rd Qu.: 20.77    3rd Qu.: 29.17       3rd Qu.: 18.75        3rd Qu.: 22.49
#  Max.   :177.01    Max.   :331.53       Max.   :150.11        Max.   :100.00
#
#   CO_SubIndex       SO2_SubIndex  NO2_SubIndex     NO2_CAPS_SubIndex
#  Min.   : 0.0000   Min.   :0     Min.   :  0.000   Min.   :0
#  1st Qu.: 0.9616   1st Qu.:0     1st Qu.:  9.217   1st Qu.:0
#  Median : 2.2813   Median :0     Median : 15.566   Median :0
#  Mean   : 2.5672   Mean   :0     Mean   : 16.581   Mean   :0
#  3rd Qu.: 3.7713   3rd Qu.:0     3rd Qu.: 22.962   3rd Qu.:0
#  Max.   :24.0662   Max.   :0     Max.   :100.988   Max.   :0
#
#  AQI_calculated    AQI_bucket_calculated precip_accum_one_hour_set_1
#  Min.   :  0.00   Good        :67524     Min.   : 0.00
#  1st Qu.: 23.00   Moderate    :  637     1st Qu.: 0.03
#  Median : 28.00   Poor        :   63     Median : 0.25
#  Mean   : 31.82   Satisfactory: 5298     Mean   : 0.52
#  3rd Qu.: 36.00                          3rd Qu.: 0.68
#  Max.   :239.00                          Max.   :23.25
#                                          NA's   :60214
#  Fremont_Total     Fremont_East     Fremont_West    Spokane_Total
#  Min.   :   0.0   Min.   :  0.00   Min.   :  0.00   Min.   :  0.00
#  1st Qu.:  13.0   1st Qu.:  6.00   1st Qu.:  7.00   1st Qu.:  4.00
#  Median :  61.0   Median : 27.00   Median : 32.00   Median : 18.00
#  Mean   : 109.8   Mean   : 47.82   Mean   : 61.95   Mean   : 33.08
#  3rd Qu.: 148.0   3rd Qu.: 66.00   3rd Qu.: 79.00   3rd Qu.: 46.00
#  Max.   :1097.0   Max.   :584.00   Max.   :850.00   Max.   :431.00
#  NA's   :1849     NA's   :1849     NA's   :1849     NA's   :3135
#   Spokane_West     Spokane_East
#  Min.   :  0.00   Min.   :  0.0
#  1st Qu.:  2.00   1st Qu.:  2.0
#  Median :  6.00   Median :  7.0
#  Mean   : 16.22   Mean   : 16.6
#  3rd Qu.: 18.00   3rd Qu.: 20.0
#  Max.   :367.00   Max.   :330.0
#  NA's   :2391     NA's   :2391

# %%
colnames(beacon2)
# Out:
#  [1] "Site"                        "Date"
#  [3] "CO"                          "NO2_caps"
#  [5] "ozone"                       "PM2.5_MO"
#  [7] "PM2.5_FEM"                   "RH"
#  [9] "SO2"                         "Temperature"
# [11] "Temperature_10_m"            "Wind_Direction_s"
# [13] "Wind_Direction_v"            "Wind_Speed_p"
# [15] "Wind_Speed_s"                "DOY"
# [17] "Ozone_8hr_avg"               "PM2.5_MO_24hr_avg"
# [19] "PM2.5_FEM_24hr_avg"          "CO_8hr_avg"
# [21] "PM2.5MO_SubIndex"            "PM2.5FEM_SubIndex"
# [23] "PM2.5_1hrMO_SubIndex"        "PM2.5_1hrFEM_SubIndex"
# [25] "X03_SubIndex"                "CO_SubIndex"
# [27] "SO2_SubIndex"                "NO2_SubIndex"
# [29] "NO2_CAPS_SubIndex"           "AQI_calculated"
# [31] "AQI_bucket_calculated"       "precip_accum_one_hour_set_1"
# [33] "Fremont_Total"               "Fremont_East"
# [35] "Fremont_West"                "Spokane_Total"
# [37] "Spokane_West"                "Spokane_East"

# %%
beacon3= beacon2%>% 
  select('Spokane_Total','precip_accum_one_hour_set_1', 'PM2.5_FEM', 'Temperature_10_m','RH','AQI_calculated', )

#head(saq2)

beacon3= drop_na(beacon3)

corr_all<- round(cor(beacon3, method = c("spearman")), 3)
corr_all

nrow(beacon3)
nrow(beacon2)
nrow(weller)
nrow(beacon2)+nrow(weller)
# Out:
#                             Spokane_Total precip_accum_one_hour_set_1 PM2.5_FEM
# Spokane_Total                1.000        -0.085                       0.025
# precip_accum_one_hour_set_1 -0.085         1.000                      -0.059
# PM2.5_FEM                    0.025        -0.059                       1.000
# Temperature_10_m             0.304         0.004                      -0.066
# RH                          -0.264         0.226                       0.076
# AQI_calculated               0.004        -0.010                       0.050
#                             Temperature_10_m RH     AQI_calculated
# Spokane_Total                0.304           -0.264  0.004
# precip_accum_one_hour_set_1  0.004            0.226 -0.010
# PM2.5_FEM                   -0.066            0.076  0.050
# Temperature_10_m             1.000           -0.263 -0.041
# RH                          -0.263            1.000  0.012
# AQI_calculated              -0.041            0.012  1.000
# [1] 5426
# [1] 94075
# [1] 73522
# [1] 167597

# %%
options(repr.plot.width=6, repr.plot.height=4)

# Function to add histograms
panel.hist <- function(x, ...) {
    usr <- par("usr")
    on.exit(par(usr))
    par(usr = c(usr[1:2], 0, 1.5))
    his <- hist(x, plot = FALSE)
    breaks <- his$breaks
    nB <- length(breaks)
    y <- his$counts
    y <- y/max(y)
    rect(breaks[-nB], 0, breaks[-1], y, col = rgb(0, 1, 1, alpha = 0.5), ...)
    # lines(density(x), col = 2, lwd = 2) # Uncomment to add density lines
}

# Creating the scatter plot matrix
pairs(beacon3,
      upper.panel = NULL,         # Disabling the upper panel
      diag.panel = panel.hist)    # Adding the histograms
# Out:
# plot without title

# %% [markdown]
# ## Time series analysis

# %%
options(repr.plot.width=7, repr.plot.height=5)

ggplot(df, aes(x = Date, y = PM2.5_FEM, color = Site)) +
     geom_line(size = 1.5) +# facet_wrap(~  AQI_bucket_calculated, ncol=1)+
     theme_bw()+
    ylab('Freemont Bridge Hourly Bike Counts') +
    xlab('Date') +
    guides(color=guide_legend(title="AQI Index Category"))+
    theme_bw()
# Out:
# Warning message:
# “Removed 74289 rows containing missing values (geom_path).”
# plot without title

# %%
colnames(df)
# Out:
#  [1] "Site"                        "Date"
#  [3] "CO"                          "NO2"
#  [5] "NO2_caps"                    "ozone"
#  [7] "PM2.5_MO"                    "PM2.5_FEM"
#  [9] "RH"                          "SO2"
# [11] "Temperature"                 "Temperature_10_m"
# [13] "Wind_Direction_s"            "Wind_Direction_v"
# [15] "Wind_Speed_p"                "Wind_Speed_s"
# [17] "DOY"                         "Ozone_8hr_avg"
# [19] "PM2.5_MO_24hr_avg"           "PM2.5_FEM_24hr_avg"
# [21] "CO_8hr_avg"                  "PM2.5MO_SubIndex"
# [23] "PM2.5FEM_SubIndex"           "PM2.5_1hrMO_SubIndex"
# [25] "PM2.5_1hrFEM_SubIndex"       "X03_SubIndex"
# [27] "CO_SubIndex"                 "SO2_SubIndex"
# [29] "NO2_SubIndex"                "NO2_CAPS_SubIndex"
# [31] "AQI_calculated"              "AQI_bucket_calculated"
# [33] "precip_accum_one_hour_set_1" "Fremont_Total"
# [35] "Fremont_East"                "Fremont_West"
# [37] "Spokane_Total"               "Spokane_West"
# [39] "Spokane_East"

# %%
df$mPM = df$PM2.5_FEM  # your new merged column start with x
df$mPM[!is.na(df$PM2.5_MO)] = df$PM2.5_MO[!is.na(df$PM2.5_MO)]  # merge with y

#df$mpm
head(df,3)
# Out:
#   Site                Date       CO NO2 NO2_caps ozone PM2.5_MO PM2.5_FEM RH
# 1 Seattle Beacon Hill 2012-01-01 NA NA  NA       10    NA       10.3      71
# 2 Seattle Beacon Hill 2012-01-01 NA NA  NA       30    NA        3.0      64
# 3 Seattle Beacon Hill 2012-01-01 NA NA  NA       30    NA        2.3      65
#   SO2 ... AQI_calculated AQI_bucket_calculated precip_accum_one_hour_set_1
# 1 NA  ... 0              Good                  NA
# 2 NA  ... 0              Good                  NA
# 3 NA  ... 0              Good                  NA
#   Fremont_Total Fremont_East Fremont_West Spokane_Total Spokane_West
# 1 NA            NA           NA           NA            NA
# 2 NA            NA           NA           NA            NA
# 3 NA            NA           NA           NA            NA
#   Spokane_East mPM
# 1 NA           10.3
# 2 NA            3.0
# 3 NA            2.3

# %%
df$mNO2 = df$NO2  # your new merged column start with x
df$mNO2[!is.na(df$NO2_caps)] = df$NO2_caps[!is.na(df$NO2_caps)]  # merge with y

#df$mpm
head(df,3)
# Out:
#   Site                Date       CO NO2 NO2_caps ozone PM2.5_MO PM2.5_FEM RH
# 1 Seattle Beacon Hill 2012-01-01 NA NA  NA       10    NA       10.3      71
# 2 Seattle Beacon Hill 2012-01-01 NA NA  NA       30    NA        3.0      64
# 3 Seattle Beacon Hill 2012-01-01 NA NA  NA       30    NA        2.3      65
#   SO2 ... AQI_bucket_calculated precip_accum_one_hour_set_1 Fremont_Total
# 1 NA  ... Good                  NA                          NA
# 2 NA  ... Good                  NA                          NA
# 3 NA  ... Good                  NA                          NA
#   Fremont_East Fremont_West Spokane_Total Spokane_West Spokane_East mPM  mNO2
# 1 NA           NA           NA            NA           NA           10.3 NA
# 2 NA           NA           NA            NA           NA            3.0 NA
# 3 NA           NA           NA            NA           NA            2.3 NA

# %%
dfD$mPM = dfD$PM2.5_FEM  # your new merged column start with x
dfD$mPM[!is.na(dfD$PM2.5_MO)] = dfD$PM2.5_MO[!is.na(dfD$PM2.5_MO)]  # merge with y

#df$mpm
head(dfD,3)
# Out:
#   X Site                  Date       CO NO2 NO2_caps ozone PM2.5_MO PM2.5_FEM
# 1 0 Seattle 10th & Weller 2014-05-21 NA NA  NA       NA    NA       9.100000
# 2 1 Seattle 10th & Weller 2014-05-22 NA NA  NA       NA    NA       8.336364
# 3 2 Seattle 10th & Weller 2014-05-23 NA NA  NA       NA    NA       6.591667
#   RH ... Fremont.Bridge.Total Fremont.Bridge.East.Sidewalk
# 1 NA ... 5229                 2666
# 2 NA ... 4910                 2473
# 3 NA ... 2556                 1308
#   Fremont.Bridge.West.Sidewalk Spokane.St..Bridge.Total West East
# 1 2563                         1518                     729  789
# 2 2437                         1551                     756  795
# 3 1248                          751                     359  392
#   precip_accum_one_hour_set_1 AQI_bucket_calculated AQI_calculated_where
# 1 0.00                        Good                  PM2.5FEM_SubIndex
# 2 0.00                        Good                  PM2.5FEM_SubIndex
# 3 3.14                        Good                  PM2.5FEM_SubIndex
#   mPM
# 1 9.100000
# 2 8.336364
# 3 6.591667

# %%
dfD$mNO2 = dfD$NO2  # your new merged column start with x
dfD$mNO2[!is.na(dfD$NO2_caps)] = dfD$NO2_caps[!is.na(dfD$NO2_caps)]  # merge with y

#df$mpm
head(dfD,3)
# Out:
#   X Site                  Date       CO NO2 NO2_caps ozone PM2.5_MO PM2.5_FEM
# 1 0 Seattle 10th & Weller 2014-05-21 NA NA  NA       NA    NA       9.100000
# 2 1 Seattle 10th & Weller 2014-05-22 NA NA  NA       NA    NA       8.336364
# 3 2 Seattle 10th & Weller 2014-05-23 NA NA  NA       NA    NA       6.591667
#   RH ... Fremont.Bridge.East.Sidewalk Fremont.Bridge.West.Sidewalk
# 1 NA ... 2666                         2563
# 2 NA ... 2473                         2437
# 3 NA ... 1308                         1248
#   Spokane.St..Bridge.Total West East precip_accum_one_hour_set_1
# 1 1518                     729  789  0.00
# 2 1551                     756  795  0.00
# 3  751                     359  392  3.14
#   AQI_bucket_calculated AQI_calculated_where mPM      mNO2
# 1 Good                  PM2.5FEM_SubIndex    9.100000 NA
# 2 Good                  PM2.5FEM_SubIndex    8.336364 NA
# 3 Good                  PM2.5FEM_SubIndex    6.591667 NA

# %%
options(repr.plot.width=8, repr.plot.height=3)

ggplot(dfD, aes(x = Date, y = mNO2, color = Site)) +
     geom_line(size = .3) + facet_wrap(~  Site, ncol=1)+
     theme_bw()+
    ylab('NO2 (ppm)') +
    xlab('Date') +
    guides(color=guide_legend(title="Site"))+
    theme_bw()
# Out:
# Warning message:
# “Removed 2268 rows containing missing values (geom_path).”
# plot without title

# %%
dfD
# Out:
#      X    Site                  Date       CO        NO2      NO2_caps
# 1     0   Seattle 10th & Weller 2014-05-21        NA       NA NA
# 2     1   Seattle 10th & Weller 2014-05-22        NA       NA NA
# 3     2   Seattle 10th & Weller 2014-05-23        NA       NA NA
# 4     3   Seattle 10th & Weller 2014-05-24        NA       NA NA
# 5     4   Seattle 10th & Weller 2014-05-25        NA       NA NA
# 6     5   Seattle 10th & Weller 2014-05-26        NA       NA NA
# 7     6   Seattle 10th & Weller 2014-05-27        NA       NA NA
# 8     7   Seattle 10th & Weller 2014-05-28        NA       NA NA
# 9     8   Seattle 10th & Weller 2014-05-29        NA       NA NA
# 10    9   Seattle 10th & Weller 2014-05-30        NA       NA NA
# 11   10   Seattle 10th & Weller 2014-05-31        NA       NA NA
# 12   11   Seattle 10th & Weller 2014-06-01        NA 23.35667 NA
# 13   12   Seattle 10th & Weller 2014-06-02        NA 31.12118 NA
# 14   13   Seattle 10th & Weller 2014-06-03        NA 23.43133 NA
# 15   14   Seattle 10th & Weller 2014-06-04        NA 29.06450 NA
# 16   15   Seattle 10th & Weller 2014-06-05        NA 28.06750 NA
# 17   16   Seattle 10th & Weller 2014-06-06        NA 26.87050 NA
# 18   17   Seattle 10th & Weller 2014-06-07        NA 12.82875 NA
# 19   18   Seattle 10th & Weller 2014-06-08        NA 13.97458 NA
# 20   19   Seattle 10th & Weller 2014-06-09        NA 15.39762 NA
# 21   20   Seattle 10th & Weller 2014-06-10        NA 16.61125 NA
# 22   21   Seattle 10th & Weller 2014-06-11 0.5018800 21.85550 NA
# 23   22   Seattle 10th & Weller 2014-06-12 0.5105417 20.38792 NA
# 24   23   Seattle 10th & Weller 2014-06-13 0.5360300 23.37700 NA
# 25   24   Seattle 10th & Weller 2014-06-14 0.3973000 13.30167 NA
# 26   25   Seattle 10th & Weller 2014-06-15 0.3565167 11.40250 NA
# 27   26   Seattle 10th & Weller 2014-06-16 0.6321500 26.13900 NA
# 28   27   Seattle 10th & Weller 2014-06-17 0.4309208 16.73417 NA
# 29   28   Seattle 10th & Weller 2014-06-18 0.6559750 31.28687 NA
# 30   29   Seattle 10th & Weller 2014-06-19 0.5020045 20.68909 NA
# ...  ...  ...                   ...        ...       ...      ...
# 6988 7041 Seattle Beacon Hill   2022-10-16 0.3148304 NA       19.059545
# 6989 7042 Seattle Beacon Hill   2022-10-17 0.2599833 NA       12.606087
# 6990 7043 Seattle Beacon Hill   2022-10-18 0.5025762 NA       22.998750
# 6991 7044 Seattle Beacon Hill   2022-10-19 0.9792542 NA       18.177917
# 6992 7045 Seattle Beacon Hill   2022-10-20 1.0528348 NA       22.321667
# 6993 7046 Seattle Beacon Hill   2022-10-21 0.1313000 NA        8.064783
# 6994 7047 Seattle Beacon Hill   2022-10-22 0.1615583 NA        8.312917
# 6995 7048 Seattle Beacon Hill   2022-10-23 0.2284609 NA       10.631818
# 6996 7049 Seattle Beacon Hill   2022-10-24 0.1528917 NA        7.404348
# 6997 7050 Seattle Beacon Hill   2022-10-25 0.1497667 NA        8.626250
# 6998 7051 Seattle Beacon Hill   2022-10-26 0.1690500 NA        8.577917
# 6999 7052 Seattle Beacon Hill   2022-10-27 0.1402739 NA        5.592917
# 7000 7053 Seattle Beacon Hill   2022-10-28 0.1909708 NA        8.329565
# 7001 7054 Seattle Beacon Hill   2022-10-29 0.2369958 NA       10.020417
# 7002 7055 Seattle Beacon Hill   2022-10-30 0.1407478 NA        4.884091
# 7003 7056 Seattle Beacon Hill   2022-10-31 0.1348000 NA        4.773913
# 7004 7057 Seattle Beacon Hill   2022-11-01 0.1957292 NA        9.390417
# 7005 7058 Seattle Beacon Hill   2022-11-02 0.2184792 NA       13.119583
# 7006 7059 Seattle Beacon Hill   2022-11-03 0.2530348 NA       12.882917
# 7007 7060 Seattle Beacon Hill   2022-11-04 0.1310292 NA        3.651739
# 7008 7061 Seattle Beacon Hill   2022-11-05 0.1365750 NA        5.991667
# 7009 7062 Seattle Beacon Hill   2022-11-06 0.1400435 NA        5.605000
# 7010 7063 Seattle Beacon Hill   2022-11-07 0.1782500 NA        9.431304
# 7011 7064 Seattle Beacon Hill   2022-11-08 0.1599875 NA        4.412083
# 7012 7065 Seattle Beacon Hill   2022-11-09 0.2184167 NA        9.475417
# 7013 7066 Seattle Beacon Hill   2022-11-10 0.3030261 NA       15.200417
# 7014 7067 Seattle Beacon Hill   2022-11-11 0.2943208 NA       17.546522
# 7015 7068 Seattle Beacon Hill   2022-11-12 0.2694875 NA       12.009167
# 7016 7069 Seattle Beacon Hill   2022-11-13 0.2897913 NA        9.567273
# 7017 7070 Seattle Beacon Hill   2022-11-14 0.2112467 NA        7.787857
#      ozone    PM2.5_MO   PM2.5_FEM RH  ... Fremont.Bridge.East.Sidewalk
# 1    NA       NA          9.100000 NA  ... 2666
# 2    NA       NA          8.336364 NA  ... 2473
# 3    NA       NA          6.591667 NA  ... 1308
# 4    NA       NA          5.625000 NA  ... 1124
# 5    NA       NA          6.104167 NA  ...  670
# 6    NA       NA          4.195833 NA  ... 1260
# 7    NA       NA          4.766667 NA  ... 2562
# 8    NA       NA          6.921739 NA  ... 2078
# 9    NA       NA          9.360870 NA  ... 2300
# 10   NA       NA          8.254167 NA  ... 2437
# 11   NA       NA         10.600000 NA  ... 1609
# 12   NA       NA          9.950000 NA  ... 1438
# 13   NA       NA         13.822727 NA  ... 2427
# 14   NA       NA          9.500000 NA  ... 2371
# 15   NA       NA         11.309091 NA  ... 2463
# 16   NA       NA         10.808333 NA  ... 2322
# 17   NA       NA          9.433333 NA  ... 2200
# 18   NA       NA          4.537500 NA  ... 1529
# 19   NA       NA          5.812500 NA  ... 1900
# 20   NA       NA          5.320833 NA  ... 2040
# 21   NA       NA          7.483333 NA  ... 2253
# 22   NA       NA          8.125000 NA  ... 2654
# 23   NA       NA          5.728571 NA  ... 2098
# 24   NA       NA          7.795833 NA  ... 1131
# 25   NA       NA          8.091667 NA  ...  955
# 26   NA       NA          5.312500 NA  ...  720
# 27   NA       NA          6.016667 NA  ... 1689
# 28   NA       NA          6.708333 NA  ... 2075
# 29   NA       NA          8.744444 NA  ... 2380
# 30   NA       NA          6.458333 NA  ... 2248
# ...  ...      ...        ...       ...     ...
# 6988 23.18182  20.666667 NA        NA  ... NA
# 6989 22.08333  16.000000 NA        NA  ... NA
# 6990 18.18182  34.166667 NA        NA  ... NA
# 6991 22.17391 110.416667 NA        NA  ... NA
# 6992 18.82353 105.875000 NA        NA  ... NA
# 6993 25.41667   5.708333 NA        NA  ... NA
# 6994 17.91667   4.739130 NA        NA  ... NA
# 6995 14.54545   7.333333 NA        NA  ... NA
# 6996 21.25000   4.458333 NA        NA  ... NA
# 6997 24.54545   3.304348 NA        NA  ... NA
# 6998 24.16667   5.416667 NA        NA  ... NA
# 6999 34.34783   6.000000 NA        NA  ... NA
# 7000 25.21739   6.041667 NA        NA  ... NA
# 7001 18.26087   9.333333 NA        NA  ... NA
# 7002 28.26087   5.291667 NA        NA  ... NA
# 7003 30.41667   3.727273 NA        NA  ... NA
# 7004 19.54545   5.952381 NA        NA  ... NA
# 7005 19.56522   5.625000 NA        NA  ... NA
# 7006 12.22222   9.041667 NA        NA  ... NA
# 7007 25.00000   3.714286 NA        NA  ... NA
# 7008 27.91667   4.333333 NA        NA  ... NA
# 7009 30.00000   2.000000 NA        NA  ... NA
# 7010 22.50000   3.750000 NA        NA  ... NA
# 7011 24.54545   6.791667 NA        NA  ... NA
# 7012 18.33333   9.750000 NA        NA  ... NA
# 7013 13.12500  12.833333 NA        NA  ... NA
# 7014 11.05263   9.416667 NA        NA  ... NA
# 7015 14.54545  13.000000 NA        NA  ... NA
# 7016 15.88235  14.041667 NA        NA  ... NA
# 7017 11.33333  10.866667 NA        NA  ... NA
#      Fremont.Bridge.West.Sidewalk Spokane.St..Bridge.Total West East
# 1    2563                         1518                     729  789
# 2    2437                         1551                     756  795
# 3    1248                          751                     359  392
# 4    1031                          654                     336  318
# 5     564                          366                     186  180
# 6    1029                          652                     323  329
# 7    2470                         1482                     722  760
# 8    1930                         1061                     507  554
# 9    2287                         1353                     651  702
# 10   2432                         1477                     732  745
# 11   1278                         1104                     541  563
# 12   1163                          844                     417  427
# 13   2487                         1347                     660  687
# 14   2299                         1416                     680  736
# 15   2400                         1392                     678  714
# 16   2353                         1404                     709  695
# 17   2182                         1236                     598  638
# 18   1278                         1009                     512  497
# 19   1647                          799                     394  405
# 20   2088                         1173                     581  592
# 21   2277                         1294                     629  665
# 22   2542                         1492                     734  758
# 23   1979                         1133                     525  608
# 24   1135                          558                     287  271
# 25    818                          695                     339  356
# 26    547                          455                     220  235
# 27   1672                          902                     441  461
# 28   2032                         1079                     519  560
# 29   2270                         1220                     496  724
# 30   2164                         1270                     627  643
# ...  ...                          ...                      ...  ...
# 6988 NA                           NA                       NA   NA
# 6989 NA                           NA                       NA   NA
# 6990 NA                           NA                       NA   NA
# 6991 NA                           NA                       NA   NA
# 6992 NA                           NA                       NA   NA
# 6993 NA                           NA                       NA   NA
# 6994 NA                           NA                       NA   NA
# 6995 NA                           NA                       NA   NA
# 6996 NA                           NA                       NA   NA
# 6997 NA                           NA                       NA   NA
# 6998 NA                           NA                       NA   NA
# 6999 NA                           NA                       NA   NA
# 7000 NA                           NA                       NA   NA
# 7001 NA                           NA                       NA   NA
# 7002 NA                           NA                       NA   NA
# 7003 NA                           NA                       NA   NA
# 7004 NA                           NA                       NA   NA
# 7005 NA                           NA                       NA   NA
# 7006 NA                           NA                       NA   NA
# 7007 NA                           NA                       NA   NA
# 7008 NA                           NA                       NA   NA
# 7009 NA                           NA                       NA   NA
# 7010 NA                           NA                       NA   NA
# 7011 NA                           NA                       NA   NA
# 7012 NA                           NA                       NA   NA
# 7013 NA                           NA                       NA   NA
# 7014 NA                           NA                       NA   NA
# 7015 NA                           NA                       NA   NA
# 7016 NA                           NA                       NA   NA
# 7017 NA                           NA                       NA   NA
#      precip_accum_one_hour_set_1 AQI_bucket_calculated AQI_calculated_where
# 1    0.000000                    Good                  PM2.5FEM_SubIndex
# 2    0.000000                    Good                  PM2.5FEM_SubIndex
# 3    3.140000                    Good                  PM2.5FEM_SubIndex
# 4    0.000000                    Satisfactory          PM2.5FEM_SubIndex
# 5    0.600000                    Good                  PM2.5FEM_SubIndex
# 6    4.606667                    Good                  PM2.5FEM_SubIndex
# 7    0.000000                    Good                  PM2.5FEM_SubIndex
# 8    0.000000                    Good                  PM2.5FEM_SubIndex
# 9    0.090000                    Good                  PM2.5FEM_SubIndex
# 10   0.000000                    Good                  PM2.5FEM_SubIndex
# 11   0.000000                    Good                  PM2.5FEM_SubIndex
# 12   0.000000                    Good                  NO2_SubIndex
# 13   0.000000                    Good                  PM2.5FEM_SubIndex
# 14   0.000000                    Good                  PM2.5FEM_SubIndex
# 15   0.000000                    Good                  NO2_SubIndex
# 16   0.000000                    Good                  NO2_SubIndex
# 17   0.000000                    Good                  NO2_SubIndex
# 18   0.000000                    Good                  NO2_SubIndex
# 19   0.000000                    Good                  NO2_SubIndex
# 20   0.030000                    Good                  PM2.5FEM_SubIndex
# 21   0.000000                    Good                  PM2.5FEM_SubIndex
# 22   0.000000                    Good                  PM2.5FEM_SubIndex
# 23   0.000000                    Good                  PM2.5FEM_SubIndex
# 24   8.026667                    Good                  PM2.5FEM_SubIndex
# 25   0.000000                    Good                  PM2.5FEM_SubIndex
# 26   0.370000                    Good                  PM2.5FEM_SubIndex
# 27   3.990000                    Good                  NO2_SubIndex
# 28   1.200000                    Good                  PM2.5FEM_SubIndex
# 29   0.000000                    Good                  PM2.5FEM_SubIndex
# 30   0.000000                    Good                  PM2.5FEM_SubIndex
# ...  ...                         ...                   ...
# 6988  0.000000                   Good                  03_SubIndex
# 6989  0.000000                   Good                  PM2.5MO_SubIndex
# 6990  0.000000                   Good                  PM2.5MO_SubIndex
# 6991  0.000000                   Good                  PM2.5MO_SubIndex
# 6992  0.060000                   Good                  PM2.5MO_SubIndex
# 6993  2.478814                   Satisfactory          PM2.5MO_SubIndex
# 6994 11.723708                   Good                  PM2.5MO_SubIndex
# 6995  1.020000                   Good                  PM2.5MO_SubIndex
# 6996  2.261987                   Satisfactory          PM2.5MO_SubIndex
# 6997  3.085743                   Satisfactory          PM2.5MO_SubIndex
# 6998  5.660372                   Satisfactory          PM2.5MO_SubIndex
# 6999  0.120000                   Satisfactory          PM2.5MO_SubIndex
# 7000  5.413115                   Good                  PM2.5MO_SubIndex
# 7001  0.000000                   Satisfactory          PM2.5MO_SubIndex
# 7002  0.560000                   Moderate              PM2.5MO_SubIndex
# 7003 14.987442                   Satisfactory          PM2.5MO_SubIndex
# 7004  0.000000                   Moderate              PM2.5MO_SubIndex
# 7005  3.066250                   Moderate              PM2.5MO_SubIndex
# 7006  3.263615                   Good                  PM2.5MO_SubIndex
# 7007  6.252838                   Good                  03_SubIndex
# 7008  0.250000                   Good                  03_SubIndex
# 7009  9.182352                   Good                  PM2.5MO_SubIndex
# 7010  5.486967                   Good                  03_SubIndex
# 7011  2.496250                   Good                  PM2.5MO_SubIndex
# 7012  0.000000                   Good                  PM2.5MO_SubIndex
# 7013  0.000000                   Good                  03_SubIndex
# 7014  0.060000                   Good                  03_SubIndex
# 7015        NA                   Good                  PM2.5MO_SubIndex
# 7016        NA                   Good                  PM2.5MO_SubIndex
# 7017        NA                   Satisfactory          PM2.5MO_SubIndex
#      mPM        mNO2
# 1     9.100000        NA
# 2     8.336364        NA
# 3     6.591667        NA
# 4     5.625000        NA
# 5     6.104167        NA
# 6     4.195833        NA
# 7     4.766667        NA
# 8     6.921739        NA
# 9     9.360870        NA
# 10    8.254167        NA
# 11   10.600000        NA
# 12    9.950000  23.35667
# 13   13.822727  31.12118
# 14    9.500000  23.43133
# 15   11.309091  29.06450
# 16   10.808333  28.06750
# 17    9.433333  26.87050
# 18    4.537500  12.82875
# 19    5.812500  13.97458
# 20    5.320833  15.39762
# 21    7.483333  16.61125
# 22    8.125000  21.85550
# 23    5.728571  20.38792
# 24    7.795833  23.37700
# 25    8.091667  13.30167
# 26    5.312500  11.40250
# 27    6.016667  26.13900
# 28    6.708333  16.73417
# 29    8.744444  31.28687
# 30    6.458333  20.68909
# ...  ...        ...
# 6988  20.666667 19.059545
# 6989  16.000000 12.606087
# 6990  34.166667 22.998750
# 6991 110.416667 18.177917
# 6992 105.875000 22.321667
# 6993   5.708333  8.064783
# 6994   4.739130  8.312917
# 6995   7.333333 10.631818
# 6996   4.458333  7.404348
# 6997   3.304348  8.626250
# 6998   5.416667  8.577917
# 6999   6.000000  5.592917
# 7000   6.041667  8.329565
# 7001   9.333333 10.020417
# 7002   5.291667  4.884091
# 7003   3.727273  4.773913
# 7004   5.952381  9.390417
# 7005   5.625000 13.119583
# 7006   9.041667 12.882917
# 7007   3.714286  3.651739
# 7008   4.333333  5.991667
# 7009   2.000000  5.605000
# 7010   3.750000  9.431304
# 7011   6.791667  4.412083
# 7012   9.750000  9.475417
# 7013  12.833333 15.200417
# 7014   9.416667 17.546522
# 7015  13.000000 12.009167
# 7016  14.041667  9.567273
# 7017  10.866667  7.787857

# %%
dfpm= dfD%>% 
  select('Site','Date', 'mPM', 'PM2.5_FEM', 'PM2.5_MO')


ggplot(dfD, aes(x = Date, y = mPM, color = Site)) +
     geom_line(size = .5) + #facet_wrap(~  Site, ncol=1)+
     theme_bw()+
    ylab(expression(paste("PM 2.5 (",mu,"g/L)"))) +
    xlab('Date') +
    guides(color=guide_legend(title="Site"))+
    theme_bw()
# Out:
# plot without title

# %%
colnames(dfD)
# Out:
#  [1] "X"                            "Site"
#  [3] "Date"                         "CO"
#  [5] "NO2"                          "NO2_caps"
#  [7] "ozone"                        "PM2.5_MO"
#  [9] "PM2.5_FEM"                    "RH"
# [11] "SO2"                          "Temperature"
# [13] "Temperature_10_m"             "Wind_Direction_s"
# [15] "Wind_Direction_v"             "Wind_Speed_p"
# [17] "Wind_Speed_s"                 "Ozone_8hr_avg"
# [19] "PM2.5_MO_24hr_avg"            "PM2.5_FEM_24hr_avg"
# [21] "CO_8hr_avg"                   "PM2.5MO_SubIndex"
# [23] "PM2.5FEM_SubIndex"            "PM2.5_1hrMO_SubIndex"
# [25] "PM2.5_1hrFEM_SubIndex"        "X03_SubIndex"
# [27] "CO_SubIndex"                  "SO2_SubIndex"
# [29] "NO2_SubIndex"                 "NO2_CAPS_SubIndex"
# [31] "AQI_calculated"               "Fremont.Bridge.Total"
# [33] "Fremont.Bridge.East.Sidewalk" "Fremont.Bridge.West.Sidewalk"
# [35] "Spokane.St..Bridge.Total"     "West"
# [37] "East"                         "precip_accum_one_hour_set_1"
# [39] "AQI_bucket_calculated"        "AQI_calculated_where"
# [41] "mPM"                          "mNO2"

# %% [markdown]
# # Categories
# - CO Y
# - NO2 Y
# - Ozone only one
# - PM 2.5 Y
# - SO2 only one
# - RH
# - Temperature Y (need to remove low values)
# - AQI calculated Y
# - Percipitation

# %% [markdown]
# # Ozone

# %%
# Interleaved histograms
ggplot(dfD, aes(x=ozone, fill=Site)) +
  geom_histogram(aes(y=..count../sum(..count..)), position="dodge", binwidth=.45)+ #fill="white",
  theme(legend.position="top")+
#geom_vline(xintercept=35.5,linetype="dashed", color = "red")+
#geom_vline(data=filter(dfD, Site==" Seattle 10th & Weller"), aes(xintercept=mean(mPM)), colour="pink", linetype = "dashed")+

ylab('Frequency of Observations')+
xlab('ozone (ppb)') +
geom_rug()
# Out:
# Warning message:
# “Removed 3211 rows containing non-finite values (stat_bin).”
# plot without title

# %% [markdown]
# # SO2

# %%
# Interleaved histograms
ggplot(dfD, aes(x=SO2, fill=Site)) +
  geom_histogram(aes(y=..count../sum(..count..)), position="dodge", binwidth=.005)+ #fill="white",
  theme(legend.position="top")+
#geom_vline(xintercept=35.5,linetype="dashed", color = "red")+
#geom_vline(data=filter(dfD, Site==" Seattle 10th & Weller"), aes(xintercept=mean(mPM)), colour="pink", linetype = "dashed")+

ylab('Frequency of Observations')+
xlab('SO2 (ppb)') +
geom_rug()
# Out:
# Warning message:
# “Removed 4593 rows containing non-finite values (stat_bin).”
# plot without title

# %% [markdown]
# # CO

# %%
# Interleaved histograms
ggplot(dfD, aes(x=CO, fill=Site)) +
  geom_histogram(aes(y=..count../sum(..count..)), position="dodge", binwidth=.005)+ #fill="white",
  theme(legend.position="top")+
#geom_vline(xintercept=35.5,linetype="dashed", color = "red")+
#geom_vline(data=filter(dfD, Site==" Seattle 10th & Weller"), aes(xintercept=mean(mPM)), colour="pink", linetype = "dashed")+

ylab('Frequency of Observations')+
xlab('CO (ppm)') +
geom_rug()
# Out:
# Warning message:
# “Removed 1600 rows containing non-finite values (stat_bin).”
# plot without title

# %% [markdown]
# # PM 2.5

# %%
# Interleaved histograms
ggplot(dfD, aes(x=mPM, fill=Site)) +
  geom_histogram(aes(y=..count../sum(..count..)), position="dodge", binwidth=.2)+ #fill="white",
  theme(legend.position="top")+
#geom_vline(xintercept=35.5,linetype="dashed", color = "red")+
#geom_vline(data=filter(dfD, Site==" Seattle 10th & Weller"), aes(xintercept=mean(mPM)), colour="pink", linetype = "dashed")+

ylab('Frequency of Observations')+
xlab(expression(paste("PM 2.5 (",mu,"g/m3)"))) +
geom_rug()
# Out:
# Warning message:
# “Removed 98 rows containing non-finite values (stat_bin).”
# plot without title

# %% [markdown]
# # NO2

# %%
# Interleaved histograms
ggplot(dfD, aes(x=mNO2, fill=Site)) +
  geom_histogram(aes(y=..count../sum(..count..)), position="dodge", binwidth=.2)+ #fill="white",
  theme(legend.position="top")+
geom_vline(xintercept=101, linetype="dashed", color = "red")+
ylab('Frequency of Observations')+
xlab('NO2 (ppb)') +
geom_rug()
# Out:
# Warning message:
# “Removed 2360 rows containing non-finite values (stat_bin).”
# plot without title

# %% [markdown]
# # Temperature

# %%
# Interleaved histograms
ggplot(dfD, aes(x=Temperature_10_m, fill=Site)) +
  geom_histogram(aes(y=..count../sum(..count..)), position="dodge", binwidth=.2)+ #fill="white",
  theme(legend.position="top")+
#geom_vline(xintercept=101, linetype="dashed", color = "red")+
ylab('Frequency of Observations')+
xlab('Temperature (F)') +
  #scale_x_continuous(limits= c(10,110))
geom_rug()
# Out:
# Warning message:
# “Removed 1610 rows containing non-finite values (stat_bin).”
# plot without title

# %% [markdown]
# ## AQI

# %%
# Interleaved histograms
ggplot(dfD, aes(x= AQI_calculated, fill=Site)) +
  geom_histogram(aes(y=..count../sum(..count..)), position="dodge", binwidth=.2)+ #fill="white",
  theme(legend.position="top")+
#geom_vline(xintercept=101, linetype="dashed", color = "red")+
ylab('Frequency of Observations')+
xlab('AQI Calculated') +
geom_rug()
# Out:
# plot without title

# %%
AQI_count_class <- dfD %>% 
  group_by(Site, AQI_bucket_calculated,) %>% 
  summarise(number_cases = n())

AQI_count_class
# Out:
#   Site                  AQI_bucket_calculated number_cases
# 1 Seattle 10th & Weller Good                  2886
# 2 Seattle 10th & Weller Satisfactory           165
# 3 Seattle 10th & Weller Moderate                29
# 4 Seattle 10th & Weller Poor                     3
# 5 Seattle Beacon Hill   Good                  3601
# 6 Seattle Beacon Hill   Satisfactory           302
# 7 Seattle Beacon Hill   Moderate                28
# 8 Seattle Beacon Hill   Poor                     3

# %%
neworder <- c("Good","Satisfactory","Moderate", "Poor")
library(plyr)  ## or dplyr (transform -> mutate)
dfD <- arrange(transform(dfD,
             AQI_bucket_calculated=factor(AQI_bucket_calculated,levels=neworder)),AQI_bucket_calculated)

ggplot(dfD, aes(x=AQI_bucket_calculated, fill=AQI_Cause))  + 
    geom_bar(position="dodge") 
    #facet_wrap(~  Site, ncol=1)
# Out:
# plot without title
